# %% [markdown]
# # Region-Based LightGBM — Sequential (Non-Parallel) with Tighter Grid & Early Stopping (GPU/Colab)
#
# This notebook trains a **LightGBM** regressor on tabular data where metropolitan regions are **one-hot encoded** (e.g., `Regionname_Northern Metropolitan`).
# It runs **four held-out experiments sequentially** (north/south/east/west) with **from-scratch nested CV** (10× outer, 3× inner), using a **tighter hyperparameter grid** and **early stopping** to reduce runtime while preserving accuracy.
#
# **Runtime savers**
# - Focused grid: tune only **`num_leaves`**, **`learning_rate`**, **`min_child_samples`**, **`feature_fraction`**.
# - Fix less impactful params: `max_depth=-1`, `bagging_fraction=0.8`, `lambda_l1=0.0`, `lambda_l2=0.1`.
# - Set `n_estimators` high and rely on **early stopping** (no `n_estimators` grid).
# - Keep features as **pandas DataFrames** and use **GPU** if available.

# %% [markdown]
# ## Setup & Configuration

# %%
# !pip -q install lightgbm pandas numpy

import os, sys, math, random, json, time, itertools, datetime
import numpy as np
import pandas as pd

try:
    import lightgbm as lgb
    _lgb_ok = True
except Exception as e:
    _lgb_ok = False
    print("LightGBM import failed. Please `pip install lightgbm`. Error:", e)

DATA_PATH = 'dataset.csv'
REGION_OHE_PREFIX = "Regionname_"
METRO_KEYWORD = "Metropolitan"
REGION_NAME_MAP = {'Northern':'north','Southern':'south','Eastern':'east','Western':'west'}
TARGET_COL_CANDIDATES = ['target','Target','TARGET','price','Price','label','Label','y']

GLOBAL_SEED = 42
np.random.seed(GLOBAL_SEED); random.seed(GLOBAL_SEED)
OUTER_K = 10
INNER_K = 3

HYPERPARAM_GRID = {
    'num_leaves':        [31, 63, 127],
    'learning_rate':     [0.01, 0.05, 0.1],
    'min_child_samples': [20, 40],
    'feature_fraction':  [0.8, 1.0],
}
FIXED_PARAMS = {
    'max_depth':        -1,
    'bagging_fraction': 0.8,
    'lambda_l1':        0.0,
    'lambda_l2':        0.1,
}
N_ESTIMATORS = 2000
EARLY_STOPPING_ROUNDS = 100
VERBOSE_EARLY_STOP = False
USE_GPU_IF_AVAILABLE = True

def gpu_available_lightgbm():
    if not _lgb_ok:
        return False
    try:
        Xp = np.random.rand(64, 5)
        yp = np.random.rand(64)
        dtrain = lgb.Dataset(Xp, label=yp)
        params = {'objective':'regression','metric':'rmse','verbose':-1,'device_type':'gpu'}
        lgb.train(params, dtrain, num_boost_round=1)
        return True
    except Exception:
        return False

GPU_OK = gpu_available_lightgbm() if USE_GPU_IF_AVAILABLE else False
print("LightGBM available:", _lgb_ok, "| GPU usable:", GPU_OK)

def grid_to_list(grid):
    keys = list(grid.keys())
    vals = [grid[k] for k in keys]
    combos = []
    for comb in itertools.product(*vals):
        combos.append(dict(zip(keys, comb)))
    return combos

GRID_LIST = grid_to_list(HYPERPARAM_GRID)
TOTAL_COMBOS = len(GRID_LIST)
print("Total hyperparameter combinations:", TOTAL_COMBOS)
# Out:
# LightGBM available: True | GPU usable: True
# Total hyperparameter combinations: 36

# %% [markdown]
# ## Load Data & Derive Metropolitan Region from One-Hot Columns

# %%
if not os.path.exists(DATA_PATH):
    alt_path = '/mnt/data/dataset.csv'
    if os.path.exists(alt_path):
        DATA_PATH = alt_path

df_raw = pd.read_csv(DATA_PATH)
print("Loaded shape:", df_raw.shape)

target_col = None
for c in TARGET_COL_CANDIDATES:
    if c in df_raw.columns:
        target_col = c
        break
if target_col is None:
    numeric_cols = [c for c in df_raw.columns if pd.api.types.is_numeric_dtype(df_raw[c])]
    if not numeric_cols:
        raise ValueError("No numeric columns to infer target from. Please set the target column name explicitly.")
    target_col = numeric_cols[-1]
print("Target column:", target_col)

ohe_cols = [c for c in df_raw.columns if c.startswith(REGION_OHE_PREFIX) and METRO_KEYWORD in c]
if not ohe_cols:
    raise ValueError(f"No region OHE columns found with prefix '{REGION_OHE_PREFIX}' containing '{METRO_KEYWORD}'.")

col_to_region = {}
for c in ohe_cols:
    for k,v in REGION_NAME_MAP.items():
        if k.lower() in c.lower():
            col_to_region[c] = v
            break

ohe_cols_mapped = [c for c in ohe_cols if c in col_to_region]
if not ohe_cols_mapped:
    raise ValueError("Could not map Metropolitan OHE columns to {north,south,east,west}.")

print("Mapped OHE columns -> region:")
print({c: col_to_region[c] for c in ohe_cols_mapped})

df = df_raw.copy()
for c in ohe_cols_mapped:
    df[c] = pd.to_numeric(df[c], errors='coerce').fillna(0).astype(int)

ohe_matrix = df[ohe_cols_mapped].values
region_labels = []
for i in range(len(df)):
    row = ohe_matrix[i]
    if row.sum() <= 0:
        region_labels.append(None)
    else:
        j = int(np.argmax(row))
        region_labels.append(col_to_region[ohe_cols_mapped[j]])
df['__region_norm__'] = region_labels

before = len(df)
df = df[df['__region_norm__'].isin(['north','south','east','west'])].copy()
after = len(df)
print(f"Kept metro rows (north/south/east/west): {after}/{before}")
print(df['__region_norm__'].value_counts())

drop_cols = set([target_col, '__region_norm__'] + ohe_cols_mapped)
id_like = [c for c in df.columns if c.lower() in {'id','uid','uuid','index'}]
drop_cols.update(id_like)

X_df_all = df.drop(columns=list(drop_cols), errors='ignore')
X_df_all = pd.get_dummies(X_df_all, drop_first=True)
y_all = df[target_col].to_numpy()

feature_cols = X_df_all.columns
regions = ['north','south','east','west']
print("Feature matrix shape:", X_df_all.shape)
# Out:
# Loaded shape: (27244, 109)
# Target column: Price
# Mapped OHE columns -> region:
# {'Regionname_Eastern Metropolitan': 'east', 'Regionname_Northern Metropolitan': 'north', 'Regionname_South-Eastern Metropolitan': 'east', 'Regionname_Southern Metropolitan': 'south', 'Regionname_Western Metropolitan': 'west'}
# Kept metro rows (north/south/east/west): 26816/27244
# __region_norm__
# south    8524
# north    7864
# west     5815
# east     4613
# Name: count, dtype: int64
# Feature matrix shape: (26816, 4677)

# %% [markdown]
# ## Utilities (Metrics, K-Fold, Logging, Training with Early Stopping)

# %%
def rmse(y_true, y_pred):
    return float(np.sqrt(np.mean((y_true - y_pred) ** 2)))

def mae(y_true, y_pred):
    return float(np.mean(np.abs(y_true - y_pred)))

def r2(y_true, y_pred):
    y_true = np.asarray(y_true); y_pred = np.asarray(y_pred)
    ss_res = np.sum((y_true - y_pred) ** 2)
    ss_tot = np.sum((y_true - np.mean(y_true)) ** 2)
    return 0.0 if ss_tot == 0 else float(1 - ss_res / ss_tot)

def kfold_indices(n_samples, k=5, seed=42, shuffle=True):
    idx = np.arange(n_samples)
    if shuffle:
        rng = np.random.default_rng(seed)
        rng.shuffle(idx)
    fold_sizes = [n_samples // k] * k
    for i in range(n_samples % k):
        fold_sizes[i] += 1
    splits, start = [], 0
    for fs in fold_sizes:
        val_idx = idx[start:start+fs]
        train_idx = np.setdiff1d(idx, val_idx, assume_unique=False)
        splits.append((train_idx, val_idx))
        start += fs
    return splits

def make_logger():
    buf = []
    def log(msg, print_also=True):
        ts = datetime.datetime.now().strftime("%Y-%m-%d %H:%M:%S")
        line = f"[{ts}] {msg}"
        buf.append(line)
        if print_also: print(line)
    def dump(path):
        with open(path, "w") as f:
            f.write("\n".join(buf))
    return log, dump

def build_regressor(params, seed=GLOBAL_SEED):
    full = dict(params)
    full.update(FIXED_PARAMS)
    reg = lgb.LGBMRegressor(
        objective='regression',
        metric='rmse',
        random_state=seed,
        n_estimators=N_ESTIMATORS,
        **full
    )
    if GPU_OK:
        try: setattr(reg, 'device_type', 'gpu')
        except Exception: pass
        try: setattr(reg, 'device', 'gpu')
        except Exception: pass
    return reg

def fit_predict_with_es(reg, Xtr_df, ytr, Xva_df, yva):
    callbacks = [lgb.early_stopping(stopping_rounds=EARLY_STOPPING_ROUNDS, verbose=VERBOSE_EARLY_STOP)]
    reg.fit(Xtr_df, ytr, eval_set=[(Xva_df, yva)], callbacks=callbacks)
    num_iter = getattr(reg, 'best_iteration_', None)
    if num_iter is not None and num_iter > 0:
        pred = reg.predict(Xva_df, num_iteration=num_iter)
    else:
        pred = reg.predict(Xva_df)
    return pred

# %% [markdown]
# ## Run All Four Experiments

# %%
all_experiment_summaries = []

for held_out in regions:
    log, dump = make_logger()
    log("="*90)
    log(f"Starting experiment | HELD-OUT REGION: {held_out.upper()}")
    log("="*90)
    train_regions = sorted(list(set(regions) - {held_out}))
    log(f"Training regions: {train_regions}")

    # Masks for rows
    mask_train = df['__region_norm__'].isin(train_regions).values

    # Keep as DataFrames
    X_train_df = X_df_all.loc[mask_train, feature_cols].copy()
    y_train    = y_all[mask_train]

    log(f"Train shape: {X_train_df.shape}")
    if X_train_df.shape[0] < OUTER_K + INNER_K:
        log("Warning: Small sample sizes may distort CV results.")

    outer_splits = kfold_indices(X_train_df.shape[0], k=OUTER_K, seed=GLOBAL_SEED, shuffle=True)
    outer_results, per_fold_best = [], []

    for fold_idx, (tr_idx, va_idx) in enumerate(outer_splits, start=1):
        log("-"*70)
        log(f"Outer fold {fold_idx}/{OUTER_K}")

        X_tr_df = X_train_df.iloc[tr_idx]
        y_tr    = y_train[tr_idx]
        X_va_df = X_train_df.iloc[va_idx]
        y_va    = y_train[va_idx]

        inner_splits = kfold_indices(X_tr_df.shape[0], k=INNER_K, seed=GLOBAL_SEED + fold_idx, shuffle=True)

        best_inner_params, best_inner_score = None, float('inf')

        # ---- Inner CV: evaluate each combo with early stopping ----
        for combo_idx, cand in enumerate(GRID_LIST, start=1):
            rmses, maes, r2s = [], [], []
            for in_tr_idx, in_va_idx in inner_splits:
                X_in_tr_df = X_tr_df.iloc[in_tr_idx]
                y_in_tr    = y_tr[in_tr_idx]
                X_in_va_df = X_tr_df.iloc[in_va_idx]
                y_in_va    = y_tr[in_va_idx]

                reg = build_regressor(cand, seed=GLOBAL_SEED+fold_idx)
                pred = fit_predict_with_es(reg, X_in_tr_df, y_in_tr, X_in_va_df, y_in_va)
                rm, ma, r = rmse(y_in_va, pred), mae(y_in_va, pred), r2(y_in_va, pred)
                rmses.append(rm); maes.append(ma); r2s.append(r)

            mean_rmse = float(np.mean(rmses))
            mean_mae  = float(np.mean(maes))
            mean_r2   = float(np.mean(r2s))

            log(f"[Outer {fold_idx}] Combo {combo_idx}/{TOTAL_COMBOS} params={cand} | "
                f"Inner means -> RMSE={mean_rmse:.4f}, MAE={mean_mae:.4f}, R^2={mean_r2:.4f}")

            if mean_rmse < best_inner_score:
                best_inner_score = mean_rmse
                best_inner_params = cand

        log(f"[Outer {fold_idx}] Best inner params: {best_inner_params} (mean RMSE={best_inner_score:.4f})")

        # ---- Outer validation with chosen params + early stopping ----
        reg = build_regressor(best_inner_params, seed=GLOBAL_SEED+fold_idx)
        pred = fit_predict_with_es(reg, X_tr_df, y_tr, X_va_df, y_va)
        rm, m, r = rmse(y_va, pred), mae(y_va, pred), r2(y_va, pred)

        outer_results.append({'fold': fold_idx, 'rmse': rm, 'mae': m, 'r2': r, 'best_params': best_inner_params})
        per_fold_best.append(best_inner_params)

        log(f"[Outer {fold_idx}] Validation -> RMSE={rm:.4f}, MAE={m:.4f}, R^2={r:.4f}")

    # ---- Aggregate outer results ----
    outer_rmse = [d['rmse'] for d in outer_results]
    outer_mae  = [d['mae']  for d in outer_results]
    outer_r2   = [d['r2']   for d in outer_results]

    mean_rmse, std_rmse = float(np.mean(outer_rmse)), float(np.std(outer_rmse))
    mean_mae,  std_mae  = float(np.mean(outer_mae)),  float(np.std(outer_mae))
    mean_r2,   std_r2   = float(np.mean(outer_r2)),   float(np.std(outer_r2))

    log(f"Outer summary -> RMSE mean={mean_rmse:.4f}±{std_rmse:.4f}, "
        f"MAE mean={mean_mae:.4f}±{std_mae:.4f}, R^2 mean={mean_r2:.4f}±{std_r2:.4f}")

    # ---- Save per-region summary (PER-FOLD lines + aggregates) ----
    lines = []
    lines.append(f"=== Experiment: Held-out region = {held_out} ===\n")
    lines.append("Per-outer-fold metrics (validation on training regions):")
    for d in outer_results:
        lines.append(f"Fold {d['fold']:>2}: RMSE={d['rmse']:.6f}, MAE={d['mae']:.6f}, R2={d['r2']:.6f}, best_params={json.dumps(d['best_params'])}")
    lines.append("\nOuter-CV aggregates:")
    lines.append(f"RMSE mean={mean_rmse:.6f}, std={std_rmse:.6f}")
    lines.append(f"MAE  mean={mean_mae:.6f}, std={std_mae:.6f}")
    lines.append(f"R2   mean={mean_r2:.6f}, std={std_r2:.6f}")

    sum_name = f"summary_{held_out}.txt"
    with open(sum_name, "w") as f:
        f.write("\n".join(lines))

    # Save per-region log
    log_name = f"log_{held_out}.txt"
    dump(log_name)
    print(f"Saved per-region summary to {sum_name} and log to {log_name}")

    all_experiment_summaries.append({
        'held_out': held_out,
        'outer_results': outer_results,
        'aggregates': {'rmse_mean': mean_rmse, 'rmse_std': std_rmse,
                       'mae_mean': mean_mae, 'mae_std': std_mae,
                       'r2_mean': mean_r2, 'r2_std': std_r2},
    })

# ---- Master summary: include PER-FOLD lines for each region ----
master_lines = ["=== Master Summary: All Four Held-Out Metropolitan Regions (Sequential, No Final Fit) ===\n"]
for exp in all_experiment_summaries:
    ho = exp['held_out']
    master_lines.append(f"--- Held-out: {ho} ---")
    master_lines.append("Per-outer-fold metrics:")
    for d in exp['outer_results']:
        master_lines.append(f"  Fold {d['fold']:>2}: RMSE={d['rmse']:.6f}, MAE={d['mae']:.6f}, R2={d['r2']:.6f}")
    ag = exp['aggregates']
    master_lines.append("Aggregates:")
    master_lines.append(f"  RMSE mean={ag['rmse_mean']:.6f}, std={ag['rmse_std']:.6f}")
    master_lines.append(f"  MAE  mean={ag['mae_mean']:.6f}, std={ag['mae_std']:.6f}")
    master_lines.append(f"  R2   mean={ag['r2_mean']:.6f}, std={ag['r2_std']:.6f}")
    master_lines.append("")

with open("experiment_summary_all_regions.txt", "w") as f:
    f.write("\n".join(master_lines))

print("\nWrote combined master summary (with per-fold metrics) to experiment_summary_all_regions.txt")
# Out:
# [2025-10-14 07:32:17] ==========================================================================================
# [2025-10-14 07:32:17] Starting experiment | HELD-OUT REGION: NORTH
# [2025-10-14 07:32:17] ==========================================================================================
# [2025-10-14 07:32:17] Training regions: ['east', 'south', 'west']
# [2025-10-14 07:32:18] Train shape: (18952, 4677)
# [2025-10-14 07:32:18] ----------------------------------------------------------------------
# [2025-10-14 07:32:18] Outer fold 1/10
# [2025-10-14 07:32:30] [Outer 1] Combo 1/36 params={'num_leaves': 31, 'learning_rate': 0.01, 'min_child_samples': 20, 'feature_fraction': 0.8} | Inner means -> RMSE=299347.9864, MAE=174545.0178, R^2=0.8137
# [2025-10-14 07:32:41] [Outer 1] Combo 2/36 params={'num_leaves': 31, 'learning_rate': 0.01, 'min_child_samples': 20, 'feature_fraction': 1.0} | Inner means -> RMSE=302165.7074, MAE=176812.2815, R^2=0.8102
# [2025-10-14 07:32:52] [Outer 1] Combo 3/36 params={'num_leaves': 31, 'learning_rate': 0.01, 'min_child_samples': 40, 'feature_fraction': 0.8} | Inner means -> RMSE=300064.4491, MAE=174725.4365, R^2=0.8128
# [2025-10-14 07:33:03] [Outer 1] Combo 4/36 params={'num_leaves': 31, 'learning_rate': 0.01, 'min_child_samples': 40, 'feature_fraction': 1.0} | Inner means -> RMSE=302330.2089, MAE=176228.3098, R^2=0.8100
# [2025-10-14 07:33:08] [Outer 1] Combo 5/36 params={'num_leaves': 31, 'learning_rate': 0.05, 'min_child_samples': 20, 'feature_fraction': 0.8} | Inner means -> RMSE=299165.4492, MAE=174947.8741, R^2=0.8140
# [2025-10-14 07:33:13] [Outer 1] Combo 6/36 params={'num_leaves': 31, 'learning_rate': 0.05, 'min_child_samples': 20, 'feature_fraction': 1.0} | Inner means -> RMSE=301864.9122, MAE=176648.8352, R^2=0.8106
# [2025-10-14 07:33:18] [Outer 1] Combo 7/36 params={'num_leaves': 31, 'learning_rate': 0.05, 'min_child_samples': 40, 'feature_fraction': 0.8} | Inner means -> RMSE=300349.6219, MAE=175163.8725, R^2=0.8124
# [2025-10-14 07:33:24] [Outer 1] Combo 8/36 params={'num_leaves': 31, 'learning_rate': 0.05, 'min_child_samples': 40, 'feature_fraction': 1.0} | Inner means -> RMSE=301119.9782, MAE=175627.2104, R^2=0.8115
# [2025-10-14 07:33:28] [Outer 1] Combo 9/36 params={'num_leaves': 31, 'learning_rate': 0.1, 'min_child_samples': 20, 'feature_fraction': 0.8} | Inner means -> RMSE=301903.6427, MAE=175934.4416, R^2=0.8106
# [2025-10-14 07:33:32] [Outer 1] Combo 10/36 params={'num_leaves': 31, 'learning_rate': 0.1, 'min_child_samples': 20, 'feature_fraction': 1.0} | Inner means -> RMSE=303952.3230, MAE=177420.3307, R^2=0.8080
# [2025-10-14 07:33:36] [Outer 1] Combo 11/36 params={'num_leaves': 31, 'learning_rate': 0.1, 'min_child_samples': 40, 'feature_fraction': 0.8} | Inner means -> RMSE=301214.1614, MAE=176323.0740, R^2=0.8114
# [2025-10-14 07:33:40] [Outer 1] Combo 12/36 params={'num_leaves': 31, 'learning_rate': 0.1, 'min_child_samples': 40, 'feature_fraction': 1.0} | Inner means -> RMSE=302299.0422, MAE=177381.7406, R^2=0.8100
# [2025-10-14 07:33:54] [Outer 1] Combo 13/36 params={'num_leaves': 63, 'learning_rate': 0.01, 'min_child_samples': 20, 'feature_fraction': 0.8} | Inner means -> RMSE=300084.2222, MAE=173749.0049, R^2=0.8128
# [2025-10-14 07:34:08] [Outer 1] Combo 14/36 params={'num_leaves': 63, 'learning_rate': 0.01, 'min_child_samples': 20, 'feature_fraction': 1.0} | Inner means -> RMSE=303111.8908, MAE=175498.8232, R^2=0.8090
# [2025-10-14 07:34:23] [Outer 1] Combo 15/36 params={'num_leaves': 63, 'learning_rate': 0.01, 'min_child_samples': 40, 'feature_fraction': 0.8} | Inner means -> RMSE=301318.7849, MAE=174216.1926, R^2=0.8112
# [2025-10-14 07:34:37] [Outer 1] Combo 16/36 params={'num_leaves': 63, 'learning_rate': 0.01, 'min_child_samples': 40, 'feature_fraction': 1.0} | Inner means -> RMSE=304039.5178, MAE=176063.6965, R^2=0.8078
# [2025-10-14 07:34:42] [Outer 1] Combo 17/36 params={'num_leaves': 63, 'learning_rate': 0.05, 'min_child_samples': 20, 'feature_fraction': 0.8} | Inner means -> RMSE=300545.8716, MAE=175098.8380, R^2=0.8122
# [2025-10-14 07:34:47] [Outer 1] Combo 18/36 params={'num_leaves': 63, 'learning_rate': 0.05, 'min_child_samples': 20, 'feature_fraction': 1.0} | Inner means -> RMSE=303387.8526, MAE=176098.8749, R^2=0.8086
# [2025-10-14 07:34:52] [Outer 1] Combo 19/36 params={'num_leaves': 63, 'learning_rate': 0.05, 'min_child_samples': 40, 'feature_fraction': 0.8} | Inner means -> RMSE=302766.5812, MAE=175646.8475, R^2=0.8094
# [2025-10-14 07:34:58] [Outer 1] Combo 20/36 params={'num_leaves': 63, 'learning_rate': 0.05, 'min_child_samples': 40, 'feature_fraction': 1.0} | Inner means -> RMSE=304400.5380, MAE=176709.7357, R^2=0.8073
# [2025-10-14 07:35:02] [Outer 1] Combo 21/36 params={'num_leaves': 63, 'learning_rate': 0.1, 'min_child_samples': 20, 'feature_fraction': 0.8} | Inner means -> RMSE=301940.4534, MAE=175841.1987, R^2=0.8104
# [2025-10-14 07:35:06] [Outer 1] Combo 22/36 params={'num_leaves': 63, 'learning_rate': 0.1, 'min_child_samples': 20, 'feature_fraction': 1.0} | Inner means -> RMSE=303854.4687, MAE=177184.9380, R^2=0.8081
# [2025-10-14 07:35:11] [Outer 1] Combo 23/36 params={'num_leaves': 63, 'learning_rate': 0.1, 'min_child_samples': 40, 'feature_fraction': 0.8} | Inner means -> RMSE=304234.3238, MAE=177416.3667, R^2=0.8075
# [2025-10-14 07:35:15] [Outer 1] Combo 24/36 params={'num_leaves': 63, 'learning_rate': 0.1, 'min_child_samples': 40, 'feature_fraction': 1.0} | Inner means -> RMSE=305845.4207, MAE=178411.7734, R^2=0.8055
# [2025-10-14 07:35:31] [Outer 1] Combo 25/36 params={'num_leaves': 127, 'learning_rate': 0.01, 'min_child_samples': 20, 'feature_fraction': 0.8} | Inner means -> RMSE=301873.9609, MAE=174590.8024, R^2=0.8105
# [2025-10-14 07:35:46] [Outer 1] Combo 26/36 params={'num_leaves': 127, 'learning_rate': 0.01, 'min_child_samples': 20, 'feature_fraction': 1.0} | Inner means -> RMSE=305847.2654, MAE=176450.3989, R^2=0.8055
# [2025-10-14 07:36:02] [Outer 1] Combo 27/36 params={'num_leaves': 127, 'learning_rate': 0.01, 'min_child_samples': 40, 'feature_fraction': 0.8} | Inner means -> RMSE=303376.2488, MAE=175095.3281, R^2=0.8086
# [2025-10-14 07:36:20] [Outer 1] Combo 28/36 params={'num_leaves': 127, 'learning_rate': 0.01, 'min_child_samples': 40, 'feature_fraction': 1.0} | Inner means -> RMSE=305689.2613, MAE=176514.9446, R^2=0.8057
# [2025-10-14 07:36:26] [Outer 1] Combo 29/36 params={'num_leaves': 127, 'learning_rate': 0.05, 'min_child_samples': 20, 'feature_fraction': 0.8} | Inner means -> RMSE=302942.1246, MAE=175446.8907, R^2=0.8092
# [2025-10-14 07:36:32] [Outer 1] Combo 30/36 params={'num_leaves': 127, 'learning_rate': 0.05, 'min_child_samples': 20, 'feature_fraction': 1.0} | Inner means -> RMSE=306599.5665, MAE=177454.3868, R^2=0.8046
# [2025-10-14 07:36:38] [Outer 1] Combo 31/36 params={'num_leaves': 127, 'learning_rate': 0.05, 'min_child_samples': 40, 'feature_fraction': 0.8} | Inner means -> RMSE=304562.1056, MAE=176184.4551, R^2=0.8071
# [2025-10-14 07:36:44] [Outer 1] Combo 32/36 params={'num_leaves': 127, 'learning_rate': 0.05, 'min_child_samples': 40, 'feature_fraction': 1.0} | Inner means -> RMSE=306055.2308, MAE=177347.6152, R^2=0.8052
# [2025-10-14 07:36:49] [Outer 1] Combo 33/36 params={'num_leaves': 127, 'learning_rate': 0.1, 'min_child_samples': 20, 'feature_fraction': 0.8} | Inner means -> RMSE=305474.4978, MAE=176943.3797, R^2=0.8060
# [2025-10-14 07:36:54] [Outer 1] Combo 34/36 params={'num_leaves': 127, 'learning_rate': 0.1, 'min_child_samples': 20, 'feature_fraction': 1.0} | Inner means -> RMSE=308181.2142, MAE=178438.5152, R^2=0.8025
# [2025-10-14 07:36:58] [Outer 1] Combo 35/36 params={'num_leaves': 127, 'learning_rate': 0.1, 'min_child_samples': 40, 'feature_fraction': 0.8} | Inner means -> RMSE=308260.5121, MAE=178952.0614, R^2=0.8024
# [2025-10-14 07:37:03] [Outer 1] Combo 36/36 params={'num_leaves': 127, 'learning_rate': 0.1, 'min_child_samples': 40, 'feature_fraction': 1.0} | Inner means -> RMSE=307358.0176, MAE=178323.2516, R^2=0.8035
# [2025-10-14 07:37:03] [Outer 1] Best inner params: {'num_leaves': 31, 'learning_rate': 0.05, 'min_child_samples': 20, 'feature_fraction': 0.8} (mean RMSE=299165.4492)
# [2025-10-14 07:37:05] [Outer 1] Validation -> RMSE=298702.9669, MAE=170418.5790, R^2=0.8249
# [2025-10-14 07:37:05] ----------------------------------------------------------------------
# [2025-10-14 07:37:05] Outer fold 2/10
# [2025-10-14 07:37:15] [Outer 2] Combo 1/36 params={'num_leaves': 31, 'learning_rate': 0.01, 'min_child_samples': 20, 'feature_fraction': 0.8} | Inner means -> RMSE=304070.3016, MAE=175816.9418, R^2=0.8098
# [2025-10-14 07:37:27] [Outer 2] Combo 2/36 params={'num_leaves': 31, 'learning_rate': 0.01, 'min_child_samples': 20, 'feature_fraction': 1.0} | Inner means -> RMSE=305199.0732, MAE=176358.8008, R^2=0.8084
# [2025-10-14 07:37:38] [Outer 2] Combo 3/36 params={'num_leaves': 31, 'learning_rate': 0.01, 'min_child_samples': 40, 'feature_fraction': 0.8} | Inner means -> RMSE=302969.8393, MAE=174938.8121, R^2=0.8112
# [2025-10-14 07:37:49] [Outer 2] Combo 4/36 params={'num_leaves': 31, 'learning_rate': 0.01, 'min_child_samples': 40, 'feature_fraction': 1.0} | Inner means -> RMSE=303866.5957, MAE=175380.1115, R^2=0.8101
# [2025-10-14 07:37:54] [Outer 2] Combo 5/36 params={'num_leaves': 31, 'learning_rate': 0.05, 'min_child_samples': 20, 'feature_fraction': 0.8} | Inner means -> RMSE=305175.1242, MAE=176116.6755, R^2=0.8084
# [2025-10-14 07:37:59] [Outer 2] Combo 6/36 params={'num_leaves': 31, 'learning_rate': 0.05, 'min_child_samples': 20, 'feature_fraction': 1.0} | Inner means -> RMSE=306189.8802, MAE=176230.3044, R^2=0.8072
# [2025-10-14 07:38:04] [Outer 2] Combo 7/36 params={'num_leaves': 31, 'learning_rate': 0.05, 'min_child_samples': 40, 'feature_fraction': 0.8} | Inner means -> RMSE=304009.5293, MAE=175519.2276, R^2=0.8099
# [2025-10-14 07:38:08] [Outer 2] Combo 8/36 params={'num_leaves': 31, 'learning_rate': 0.05, 'min_child_samples': 40, 'feature_fraction': 1.0} | Inner means -> RMSE=303987.4806, MAE=175450.6462, R^2=0.8099
# [2025-10-14 07:38:12] [Outer 2] Combo 9/36 params={'num_leaves': 31, 'learning_rate': 0.1, 'min_child_samples': 20, 'feature_fraction': 0.8} | Inner means -> RMSE=305889.3159, MAE=177521.5759, R^2=0.8075
# [2025-10-14 07:38:16] [Outer 2] Combo 10/36 params={'num_leaves': 31, 'learning_rate': 0.1, 'min_child_samples': 20, 'feature_fraction': 1.0} | Inner means -> RMSE=307494.0179, MAE=178026.7142, R^2=0.8055
# [2025-10-14 07:38:20] [Outer 2] Combo 11/36 params={'num_leaves': 31, 'learning_rate': 0.1, 'min_child_samples': 40, 'feature_fraction': 0.8} | Inner means -> RMSE=304557.6650, MAE=176325.1329, R^2=0.8092
# [2025-10-14 07:38:24] [Outer 2] Combo 12/36 params={'num_leaves': 31, 'learning_rate': 0.1, 'min_child_samples': 40, 'feature_fraction': 1.0} | Inner means -> RMSE=305765.2926, MAE=177545.1449, R^2=0.8077
# [2025-10-14 07:38:36] [Outer 2] Combo 13/36 params={'num_leaves': 63, 'learning_rate': 0.01, 'min_child_samples': 20, 'feature_fraction': 0.8} | Inner means -> RMSE=304459.6588, MAE=174632.9635, R^2=0.8093
# [2025-10-14 07:38:49] [Outer 2] Combo 14/36 params={'num_leaves': 63, 'learning_rate': 0.01, 'min_child_samples': 20, 'feature_fraction': 1.0} | Inner means -> RMSE=306788.6943, MAE=175772.8816, R^2=0.8064
# [2025-10-14 07:39:02] [Outer 2] Combo 15/36 params={'num_leaves': 63, 'learning_rate': 0.01, 'min_child_samples': 40, 'feature_fraction': 0.8} | Inner means -> RMSE=305190.3737, MAE=174808.4563, R^2=0.8084
# [2025-10-14 07:39:15] [Outer 2] Combo 16/36 params={'num_leaves': 63, 'learning_rate': 0.01, 'min_child_samples': 40, 'feature_fraction': 1.0} | Inner means -> RMSE=306986.4381, MAE=175926.0726, R^2=0.8062
# [2025-10-14 07:39:20] [Outer 2] Combo 17/36 params={'num_leaves': 63, 'learning_rate': 0.05, 'min_child_samples': 20, 'feature_fraction': 0.8} | Inner means -> RMSE=305221.2002, MAE=175507.7000, R^2=0.8084
# [2025-10-14 07:39:25] [Outer 2] Combo 18/36 params={'num_leaves': 63, 'learning_rate': 0.05, 'min_child_samples': 20, 'feature_fraction': 1.0} | Inner means -> RMSE=307479.3371, MAE=176492.7822, R^2=0.8055
# [2025-10-14 07:39:30] [Outer 2] Combo 19/36 params={'num_leaves': 63, 'learning_rate': 0.05, 'min_child_samples': 40, 'feature_fraction': 0.8} | Inner means -> RMSE=306285.2957, MAE=175702.2799, R^2=0.8070
# [2025-10-14 07:39:35] [Outer 2] Combo 20/36 params={'num_leaves': 63, 'learning_rate': 0.05, 'min_child_samples': 40, 'feature_fraction': 1.0} | Inner means -> RMSE=307700.8503, MAE=176817.4929, R^2=0.8053
# [2025-10-14 07:39:39] [Outer 2] Combo 21/36 params={'num_leaves': 63, 'learning_rate': 0.1, 'min_child_samples': 20, 'feature_fraction': 0.8} | Inner means -> RMSE=308126.0018, MAE=177170.8203, R^2=0.8047
# [2025-10-14 07:39:43] [Outer 2] Combo 22/36 params={'num_leaves': 63, 'learning_rate': 0.1, 'min_child_samples': 20, 'feature_fraction': 1.0} | Inner means -> RMSE=309551.3075, MAE=178262.0837, R^2=0.8029
# [2025-10-14 07:39:47] [Outer 2] Combo 23/36 params={'num_leaves': 63, 'learning_rate': 0.1, 'min_child_samples': 40, 'feature_fraction': 0.8} | Inner means -> RMSE=307607.7834, MAE=176726.1336, R^2=0.8054
# [2025-10-14 07:39:51] [Outer 2] Combo 24/36 params={'num_leaves': 63, 'learning_rate': 0.1, 'min_child_samples': 40, 'feature_fraction': 1.0} | Inner means -> RMSE=308449.5693, MAE=177397.7738, R^2=0.8043
# [2025-10-14 07:40:06] [Outer 2] Combo 25/36 params={'num_leaves': 127, 'learning_rate': 0.01, 'min_child_samples': 20, 'feature_fraction': 0.8} | Inner means -> RMSE=305729.6284, MAE=174236.2972, R^2=0.8077
# [2025-10-14 07:40:22] [Outer 2] Combo 26/36 params={'num_leaves': 127, 'learning_rate': 0.01, 'min_child_samples': 20, 'feature_fraction': 1.0} | Inner means -> RMSE=308971.6747, MAE=176070.6312, R^2=0.8037
# [2025-10-14 07:40:36] [Outer 2] Combo 27/36 params={'num_leaves': 127, 'learning_rate': 0.01, 'min_child_samples': 40, 'feature_fraction': 0.8} | Inner means -> RMSE=307550.0307, MAE=174959.7218, R^2=0.8054
# [2025-10-14 07:40:51] [Outer 2] Combo 28/36 params={'num_leaves': 127, 'learning_rate': 0.01, 'min_child_samples': 40, 'feature_fraction': 1.0} | Inner means -> RMSE=310744.0009, MAE=177029.1053, R^2=0.8014
# [2025-10-14 07:40:57] [Outer 2] Combo 29/36 params={'num_leaves': 127, 'learning_rate': 0.05, 'min_child_samples': 20, 'feature_fraction': 0.8} | Inner means -> RMSE=307094.1862, MAE=175027.9549, R^2=0.8060
# [2025-10-14 07:41:03] [Outer 2] Combo 30/36 params={'num_leaves': 127, 'learning_rate': 0.05, 'min_child_samples': 20, 'feature_fraction': 1.0} | Inner means -> RMSE=309749.1959, MAE=176576.0532, R^2=0.8027
# [2025-10-14 07:41:09] [Outer 2] Combo 31/36 params={'num_leaves': 127, 'learning_rate': 0.05, 'min_child_samples': 40, 'feature_fraction': 0.8} | Inner means -> RMSE=308719.6643, MAE=176515.0108, R^2=0.8040
# [2025-10-14 07:41:15] [Outer 2] Combo 32/36 params={'num_leaves': 127, 'learning_rate': 0.05, 'min_child_samples': 40, 'feature_fraction': 1.0} | Inner means -> RMSE=310395.9717, MAE=177280.5136, R^2=0.8018
# [2025-10-14 07:41:19] [Outer 2] Combo 33/36 params={'num_leaves': 127, 'learning_rate': 0.1, 'min_child_samples': 20, 'feature_fraction': 0.8} | Inner means -> RMSE=308954.4554, MAE=177275.9275, R^2=0.8037
# [2025-10-14 07:41:24] [Outer 2] Combo 34/36 params={'num_leaves': 127, 'learning_rate': 0.1, 'min_child_samples': 20, 'feature_fraction': 1.0} | Inner means -> RMSE=310378.7993, MAE=177648.0110, R^2=0.8019
# [2025-10-14 07:41:29] [Outer 2] Combo 35/36 params={'num_leaves': 127, 'learning_rate': 0.1, 'min_child_samples': 40, 'feature_fraction': 0.8} | Inner means -> RMSE=309188.3312, MAE=177622.8705, R^2=0.8034
# [2025-10-14 07:41:34] [Outer 2] Combo 36/36 params={'num_leaves': 127, 'learning_rate': 0.1, 'min_child_samples': 40, 'feature_fraction': 1.0} | Inner means -> RMSE=311369.9504, MAE=179145.9385, R^2=0.8006
# [2025-10-14 07:41:34] [Outer 2] Best inner params: {'num_leaves': 31, 'learning_rate': 0.01, 'min_child_samples': 40, 'feature_fraction': 0.8} (mean RMSE=302969.8393)
# [2025-10-14 07:41:38] [Outer 2] Validation -> RMSE=270336.2234, MAE=169143.6074, R^2=0.8428
# [2025-10-14 07:41:38] ----------------------------------------------------------------------
# [2025-10-14 07:41:38] Outer fold 3/10
# [2025-10-14 07:41:49] [Outer 3] Combo 1/36 params={'num_leaves': 31, 'learning_rate': 0.01, 'min_child_samples': 20, 'feature_fraction': 0.8} | Inner means -> RMSE=301083.1259, MAE=175058.0917, R^2=0.8142
# [2025-10-14 07:41:59] [Outer 3] Combo 2/36 params={'num_leaves': 31, 'learning_rate': 0.01, 'min_child_samples': 20, 'feature_fraction': 1.0} | Inner means -> RMSE=303290.6781, MAE=176456.1058, R^2=0.8114
# [2025-10-14 07:42:10] [Outer 3] Combo 3/36 params={'num_leaves': 31, 'learning_rate': 0.01, 'min_child_samples': 40, 'feature_fraction': 0.8} | Inner means -> RMSE=300178.4950, MAE=174161.6833, R^2=0.8153
# [2025-10-14 07:42:21] [Outer 3] Combo 4/36 params={'num_leaves': 31, 'learning_rate': 0.01, 'min_child_samples': 40, 'feature_fraction': 1.0} | Inner means -> RMSE=301398.5125, MAE=175422.8396, R^2=0.8138
# [2025-10-14 07:42:26] [Outer 3] Combo 5/36 params={'num_leaves': 31, 'learning_rate': 0.05, 'min_child_samples': 20, 'feature_fraction': 0.8} | Inner means -> RMSE=301992.2440, MAE=175703.2667, R^2=0.8130
# [2025-10-14 07:42:30] [Outer 3] Combo 6/36 params={'num_leaves': 31, 'learning_rate': 0.05, 'min_child_samples': 20, 'feature_fraction': 1.0} | Inner means -> RMSE=302960.7527, MAE=175731.1054, R^2=0.8119
# [2025-10-14 07:42:35] [Outer 3] Combo 7/36 params={'num_leaves': 31, 'learning_rate': 0.05, 'min_child_samples': 40, 'feature_fraction': 0.8} | Inner means -> RMSE=301433.8465, MAE=175121.3625, R^2=0.8138
# [2025-10-14 07:42:41] [Outer 3] Combo 8/36 params={'num_leaves': 31, 'learning_rate': 0.05, 'min_child_samples': 40, 'feature_fraction': 1.0} | Inner means -> RMSE=301622.8252, MAE=175609.1995, R^2=0.8135
# [2025-10-14 07:42:44] [Outer 3] Combo 9/36 params={'num_leaves': 31, 'learning_rate': 0.1, 'min_child_samples': 20, 'feature_fraction': 0.8} | Inner means -> RMSE=301593.5775, MAE=176073.9033, R^2=0.8136
# [2025-10-14 07:42:48] [Outer 3] Combo 10/36 params={'num_leaves': 31, 'learning_rate': 0.1, 'min_child_samples': 20, 'feature_fraction': 1.0} | Inner means -> RMSE=304267.3290, MAE=176986.8687, R^2=0.8102
# [2025-10-14 07:42:52] [Outer 3] Combo 11/36 params={'num_leaves': 31, 'learning_rate': 0.1, 'min_child_samples': 40, 'feature_fraction': 0.8} | Inner means -> RMSE=301107.4578, MAE=175848.8572, R^2=0.8142
# [2025-10-14 07:42:56] [Outer 3] Combo 12/36 params={'num_leaves': 31, 'learning_rate': 0.1, 'min_child_samples': 40, 'feature_fraction': 1.0} | Inner means -> RMSE=302560.3761, MAE=177107.9061, R^2=0.8124
# [2025-10-14 07:43:08] [Outer 3] Combo 13/36 params={'num_leaves': 63, 'learning_rate': 0.01, 'min_child_samples': 20, 'feature_fraction': 0.8} | Inner means -> RMSE=300265.1380, MAE=173673.5118, R^2=0.8152
# [2025-10-14 07:43:21] [Outer 3] Combo 14/36 params={'num_leaves': 63, 'learning_rate': 0.01, 'min_child_samples': 20, 'feature_fraction': 1.0} | Inner means -> RMSE=303528.5226, MAE=175629.7188, R^2=0.8111
# [2025-10-14 07:43:34] [Outer 3] Combo 15/36 params={'num_leaves': 63, 'learning_rate': 0.01, 'min_child_samples': 40, 'feature_fraction': 0.8} | Inner means -> RMSE=301721.1832, MAE=174117.1093, R^2=0.8134
# [2025-10-14 07:43:48] [Outer 3] Combo 16/36 params={'num_leaves': 63, 'learning_rate': 0.01, 'min_child_samples': 40, 'feature_fraction': 1.0} | Inner means -> RMSE=304244.0307, MAE=175961.2099, R^2=0.8103
# [2025-10-14 07:43:53] [Outer 3] Combo 17/36 params={'num_leaves': 63, 'learning_rate': 0.05, 'min_child_samples': 20, 'feature_fraction': 0.8} | Inner means -> RMSE=301609.0325, MAE=174776.9125, R^2=0.8135
# [2025-10-14 07:43:57] [Outer 3] Combo 18/36 params={'num_leaves': 63, 'learning_rate': 0.05, 'min_child_samples': 20, 'feature_fraction': 1.0} | Inner means -> RMSE=303837.9571, MAE=175968.6499, R^2=0.8107
# [2025-10-14 07:44:03] [Outer 3] Combo 19/36 params={'num_leaves': 63, 'learning_rate': 0.05, 'min_child_samples': 40, 'feature_fraction': 0.8} | Inner means -> RMSE=302649.9054, MAE=175272.5344, R^2=0.8123
# [2025-10-14 07:44:08] [Outer 3] Combo 20/36 params={'num_leaves': 63, 'learning_rate': 0.05, 'min_child_samples': 40, 'feature_fraction': 1.0} | Inner means -> RMSE=304008.9549, MAE=176048.2482, R^2=0.8106
# [2025-10-14 07:44:12] [Outer 3] Combo 21/36 params={'num_leaves': 63, 'learning_rate': 0.1, 'min_child_samples': 20, 'feature_fraction': 0.8} | Inner means -> RMSE=302583.4084, MAE=175654.0233, R^2=0.8124
# [2025-10-14 07:44:17] [Outer 3] Combo 22/36 params={'num_leaves': 63, 'learning_rate': 0.1, 'min_child_samples': 20, 'feature_fraction': 1.0} | Inner means -> RMSE=305197.2776, MAE=176862.7940, R^2=0.8091
# [2025-10-14 07:44:20] [Outer 3] Combo 23/36 params={'num_leaves': 63, 'learning_rate': 0.1, 'min_child_samples': 40, 'feature_fraction': 0.8} | Inner means -> RMSE=304265.4068, MAE=176412.3267, R^2=0.8103
# [2025-10-14 07:44:25] [Outer 3] Combo 24/36 params={'num_leaves': 63, 'learning_rate': 0.1, 'min_child_samples': 40, 'feature_fraction': 1.0} | Inner means -> RMSE=305049.2750, MAE=177946.1553, R^2=0.8093
# [2025-10-14 07:44:38] [Outer 3] Combo 25/36 params={'num_leaves': 127, 'learning_rate': 0.01, 'min_child_samples': 20, 'feature_fraction': 0.8} | Inner means -> RMSE=301549.9043, MAE=173243.8069, R^2=0.8136
# [2025-10-14 07:44:54] [Outer 3] Combo 26/36 params={'num_leaves': 127, 'learning_rate': 0.01, 'min_child_samples': 20, 'feature_fraction': 1.0} | Inner means -> RMSE=304725.9611, MAE=175446.3572, R^2=0.8097
# [2025-10-14 07:45:10] [Outer 3] Combo 27/36 params={'num_leaves': 127, 'learning_rate': 0.01, 'min_child_samples': 40, 'feature_fraction': 0.8} | Inner means -> RMSE=303782.6342, MAE=174559.7974, R^2=0.8109
# [2025-10-14 07:45:26] [Outer 3] Combo 28/36 params={'num_leaves': 127, 'learning_rate': 0.01, 'min_child_samples': 40, 'feature_fraction': 1.0} | Inner means -> RMSE=306720.7588, MAE=176690.4809, R^2=0.8072
# [2025-10-14 07:45:32] [Outer 3] Combo 29/36 params={'num_leaves': 127, 'learning_rate': 0.05, 'min_child_samples': 20, 'feature_fraction': 0.8} | Inner means -> RMSE=302939.0936, MAE=174410.0459, R^2=0.8119
# [2025-10-14 07:45:38] [Outer 3] Combo 30/36 params={'num_leaves': 127, 'learning_rate': 0.05, 'min_child_samples': 20, 'feature_fraction': 1.0} | Inner means -> RMSE=305076.2537, MAE=176169.2814, R^2=0.8092
# [2025-10-14 07:45:43] [Outer 3] Combo 31/36 params={'num_leaves': 127, 'learning_rate': 0.05, 'min_child_samples': 40, 'feature_fraction': 0.8} | Inner means -> RMSE=304570.7796, MAE=175749.2349, R^2=0.8100
# [2025-10-14 07:45:49] [Outer 3] Combo 32/36 params={'num_leaves': 127, 'learning_rate': 0.05, 'min_child_samples': 40, 'feature_fraction': 1.0} | Inner means -> RMSE=306876.1022, MAE=176771.6917, R^2=0.8070
# [2025-10-14 07:45:54] [Outer 3] Combo 33/36 params={'num_leaves': 127, 'learning_rate': 0.1, 'min_child_samples': 20, 'feature_fraction': 0.8} | Inner means -> RMSE=303774.7184, MAE=175670.8400, R^2=0.8109
# [2025-10-14 07:45:59] [Outer 3] Combo 34/36 params={'num_leaves': 127, 'learning_rate': 0.1, 'min_child_samples': 20, 'feature_fraction': 1.0} | Inner means -> RMSE=306512.2787, MAE=177613.1919, R^2=0.8075
# [2025-10-14 07:46:03] [Outer 3] Combo 35/36 params={'num_leaves': 127, 'learning_rate': 0.1, 'min_child_samples': 40, 'feature_fraction': 0.8} | Inner means -> RMSE=306704.9259, MAE=177004.1961, R^2=0.8073
# [2025-10-14 07:46:08] [Outer 3] Combo 36/36 params={'num_leaves': 127, 'learning_rate': 0.1, 'min_child_samples': 40, 'feature_fraction': 1.0} | Inner means -> RMSE=309104.8958, MAE=178301.8495, R^2=0.8042
# [2025-10-14 07:46:08] [Outer 3] Best inner params: {'num_leaves': 31, 'learning_rate': 0.01, 'min_child_samples': 40, 'feature_fraction': 0.8} (mean RMSE=300178.4950)
# [2025-10-14 07:46:12] [Outer 3] Validation -> RMSE=266221.3975, MAE=168600.7360, R^2=0.8396
# [2025-10-14 07:46:12] ----------------------------------------------------------------------
# [2025-10-14 07:46:12] Outer fold 4/10
# [2025-10-14 07:46:24] [Outer 4] Combo 1/36 params={'num_leaves': 31, 'learning_rate': 0.01, 'min_child_samples': 20, 'feature_fraction': 0.8} | Inner means -> RMSE=300808.9708, MAE=174123.0232, R^2=0.8152
# [2025-10-14 07:46:35] [Outer 4] Combo 2/36 params={'num_leaves': 31, 'learning_rate': 0.01, 'min_child_samples': 20, 'feature_fraction': 1.0} | Inner means -> RMSE=301879.0174, MAE=175242.8484, R^2=0.8140
# [2025-10-14 07:46:47] [Outer 4] Combo 3/36 params={'num_leaves': 31, 'learning_rate': 0.01, 'min_child_samples': 40, 'feature_fraction': 0.8} | Inner means -> RMSE=301186.7228, MAE=174033.0839, R^2=0.8147
# [2025-10-14 07:46:57] [Outer 4] Combo 4/36 params={'num_leaves': 31, 'learning_rate': 0.01, 'min_child_samples': 40, 'feature_fraction': 1.0} | Inner means -> RMSE=303116.0718, MAE=175488.1731, R^2=0.8124
# [2025-10-14 07:47:02] [Outer 4] Combo 5/36 params={'num_leaves': 31, 'learning_rate': 0.05, 'min_child_samples': 20, 'feature_fraction': 0.8} | Inner means -> RMSE=300659.6322, MAE=174514.3206, R^2=0.8154
# [2025-10-14 07:47:06] [Outer 4] Combo 6/36 params={'num_leaves': 31, 'learning_rate': 0.05, 'min_child_samples': 20, 'feature_fraction': 1.0} | Inner means -> RMSE=302355.2483, MAE=175637.9222, R^2=0.8133
# [2025-10-14 07:47:11] [Outer 4] Combo 7/36 params={'num_leaves': 31, 'learning_rate': 0.05, 'min_child_samples': 40, 'feature_fraction': 0.8} | Inner means -> RMSE=302553.7230, MAE=175536.4526, R^2=0.8131
# [2025-10-14 07:47:16] [Outer 4] Combo 8/36 params={'num_leaves': 31, 'learning_rate': 0.05, 'min_child_samples': 40, 'feature_fraction': 1.0} | Inner means -> RMSE=302948.2108, MAE=175686.5997, R^2=0.8126
# [2025-10-14 07:47:20] [Outer 4] Combo 9/36 params={'num_leaves': 31, 'learning_rate': 0.1, 'min_child_samples': 20, 'feature_fraction': 0.8} | Inner means -> RMSE=302475.7604, MAE=176118.9338, R^2=0.8132
# [2025-10-14 07:47:24] [Outer 4] Combo 10/36 params={'num_leaves': 31, 'learning_rate': 0.1, 'min_child_samples': 20, 'feature_fraction': 1.0} | Inner means -> RMSE=304708.2237, MAE=176989.4862, R^2=0.8104
# [2025-10-14 07:47:27] [Outer 4] Combo 11/36 params={'num_leaves': 31, 'learning_rate': 0.1, 'min_child_samples': 40, 'feature_fraction': 0.8} | Inner means -> RMSE=304884.8933, MAE=177447.7975, R^2=0.8102
# [2025-10-14 07:47:31] [Outer 4] Combo 12/36 params={'num_leaves': 31, 'learning_rate': 0.1, 'min_child_samples': 40, 'feature_fraction': 1.0} | Inner means -> RMSE=304020.2021, MAE=176728.1324, R^2=0.8113
# [2025-10-14 07:47:44] [Outer 4] Combo 13/36 params={'num_leaves': 63, 'learning_rate': 0.01, 'min_child_samples': 20, 'feature_fraction': 0.8} | Inner means -> RMSE=300312.4001, MAE=173389.7753, R^2=0.8159
# [2025-10-14 07:47:57] [Outer 4] Combo 14/36 params={'num_leaves': 63, 'learning_rate': 0.01, 'min_child_samples': 20, 'feature_fraction': 1.0} | Inner means -> RMSE=302305.2237, MAE=174718.3787, R^2=0.8134
# [2025-10-14 07:48:11] [Outer 4] Combo 15/36 params={'num_leaves': 63, 'learning_rate': 0.01, 'min_child_samples': 40, 'feature_fraction': 0.8} | Inner means -> RMSE=302024.5403, MAE=174438.7206, R^2=0.8137
# [2025-10-14 07:48:26] [Outer 4] Combo 16/36 params={'num_leaves': 63, 'learning_rate': 0.01, 'min_child_samples': 40, 'feature_fraction': 1.0} | Inner means -> RMSE=304041.3356, MAE=176100.0597, R^2=0.8112
# [2025-10-14 07:48:31] [Outer 4] Combo 17/36 params={'num_leaves': 63, 'learning_rate': 0.05, 'min_child_samples': 20, 'feature_fraction': 0.8} | Inner means -> RMSE=300977.6790, MAE=173881.9009, R^2=0.8150
# [2025-10-14 07:48:36] [Outer 4] Combo 18/36 params={'num_leaves': 63, 'learning_rate': 0.05, 'min_child_samples': 20, 'feature_fraction': 1.0} | Inner means -> RMSE=303405.9210, MAE=175700.5140, R^2=0.8120
# [2025-10-14 07:48:41] [Outer 4] Combo 19/36 params={'num_leaves': 63, 'learning_rate': 0.05, 'min_child_samples': 40, 'feature_fraction': 0.8} | Inner means -> RMSE=303712.2407, MAE=175911.3119, R^2=0.8116
# [2025-10-14 07:48:46] [Outer 4] Combo 20/36 params={'num_leaves': 63, 'learning_rate': 0.05, 'min_child_samples': 40, 'feature_fraction': 1.0} | Inner means -> RMSE=304521.3920, MAE=176757.3886, R^2=0.8106
# [2025-10-14 07:48:50] [Outer 4] Combo 21/36 params={'num_leaves': 63, 'learning_rate': 0.1, 'min_child_samples': 20, 'feature_fraction': 0.8} | Inner means -> RMSE=303431.8742, MAE=176526.7814, R^2=0.8120
# [2025-10-14 07:48:54] [Outer 4] Combo 22/36 params={'num_leaves': 63, 'learning_rate': 0.1, 'min_child_samples': 20, 'feature_fraction': 1.0} | Inner means -> RMSE=304636.5495, MAE=176483.0494, R^2=0.8105
# [2025-10-14 07:48:58] [Outer 4] Combo 23/36 params={'num_leaves': 63, 'learning_rate': 0.1, 'min_child_samples': 40, 'feature_fraction': 0.8} | Inner means -> RMSE=305169.3115, MAE=176628.1271, R^2=0.8098
# [2025-10-14 07:49:03] [Outer 4] Combo 24/36 params={'num_leaves': 63, 'learning_rate': 0.1, 'min_child_samples': 40, 'feature_fraction': 1.0} | Inner means -> RMSE=304996.7233, MAE=177109.5281, R^2=0.8100
# [2025-10-14 07:49:18] [Outer 4] Combo 25/36 params={'num_leaves': 127, 'learning_rate': 0.01, 'min_child_samples': 20, 'feature_fraction': 0.8} | Inner means -> RMSE=302343.3409, MAE=173698.5308, R^2=0.8134
# [2025-10-14 07:49:34] [Outer 4] Combo 26/36 params={'num_leaves': 127, 'learning_rate': 0.01, 'min_child_samples': 20, 'feature_fraction': 1.0} | Inner means -> RMSE=305159.8204, MAE=175868.4957, R^2=0.8098
# [2025-10-14 07:49:50] [Outer 4] Combo 27/36 params={'num_leaves': 127, 'learning_rate': 0.01, 'min_child_samples': 40, 'feature_fraction': 0.8} | Inner means -> RMSE=303880.5661, MAE=174662.4513, R^2=0.8115
# [2025-10-14 07:50:09] [Outer 4] Combo 28/36 params={'num_leaves': 127, 'learning_rate': 0.01, 'min_child_samples': 40, 'feature_fraction': 1.0} | Inner means -> RMSE=306977.3169, MAE=177065.2632, R^2=0.8075
# [2025-10-14 07:50:15] [Outer 4] Combo 29/36 params={'num_leaves': 127, 'learning_rate': 0.05, 'min_child_samples': 20, 'feature_fraction': 0.8} | Inner means -> RMSE=303828.4023, MAE=175528.2157, R^2=0.8115
# [2025-10-14 07:50:21] [Outer 4] Combo 30/36 params={'num_leaves': 127, 'learning_rate': 0.05, 'min_child_samples': 20, 'feature_fraction': 1.0} | Inner means -> RMSE=306068.8730, MAE=176717.4272, R^2=0.8087
# [2025-10-14 07:50:27] [Outer 4] Combo 31/36 params={'num_leaves': 127, 'learning_rate': 0.05, 'min_child_samples': 40, 'feature_fraction': 0.8} | Inner means -> RMSE=305527.6644, MAE=176293.5597, R^2=0.8094
# [2025-10-14 07:50:33] [Outer 4] Combo 32/36 params={'num_leaves': 127, 'learning_rate': 0.05, 'min_child_samples': 40, 'feature_fraction': 1.0} | Inner means -> RMSE=308282.4242, MAE=178105.1846, R^2=0.8059
# [2025-10-14 07:50:38] [Outer 4] Combo 33/36 params={'num_leaves': 127, 'learning_rate': 0.1, 'min_child_samples': 20, 'feature_fraction': 0.8} | Inner means -> RMSE=306346.9948, MAE=177811.5200, R^2=0.8084
# [2025-10-14 07:50:43] [Outer 4] Combo 34/36 params={'num_leaves': 127, 'learning_rate': 0.1, 'min_child_samples': 20, 'feature_fraction': 1.0} | Inner means -> RMSE=306308.3267, MAE=177064.0385, R^2=0.8084
# [2025-10-14 07:50:47] [Outer 4] Combo 35/36 params={'num_leaves': 127, 'learning_rate': 0.1, 'min_child_samples': 40, 'feature_fraction': 0.8} | Inner means -> RMSE=306759.1037, MAE=177250.3047, R^2=0.8079
# [2025-10-14 07:50:52] [Outer 4] Combo 36/36 params={'num_leaves': 127, 'learning_rate': 0.1, 'min_child_samples': 40, 'feature_fraction': 1.0} | Inner means -> RMSE=309132.1158, MAE=179376.2021, R^2=0.8048
# [2025-10-14 07:50:52] [Outer 4] Best inner params: {'num_leaves': 63, 'learning_rate': 0.01, 'min_child_samples': 20, 'feature_fraction': 0.8} (mean RMSE=300312.4001)
# [2025-10-14 07:50:57] [Outer 4] Validation -> RMSE=269860.0646, MAE=167882.4497, R^2=0.8308
# [2025-10-14 07:50:57] ----------------------------------------------------------------------
# [2025-10-14 07:50:57] Outer fold 5/10
# [2025-10-14 07:51:10] [Outer 5] Combo 1/36 params={'num_leaves': 31, 'learning_rate': 0.01, 'min_child_samples': 20, 'feature_fraction': 0.8} | Inner means -> RMSE=293932.2258, MAE=172241.2268, R^2=0.8184
# [2025-10-14 07:51:22] [Outer 5] Combo 2/36 params={'num_leaves': 31, 'learning_rate': 0.01, 'min_child_samples': 20, 'feature_fraction': 1.0} | Inner means -> RMSE=295685.7168, MAE=173406.3400, R^2=0.8163
# [2025-10-14 07:51:34] [Outer 5] Combo 3/36 params={'num_leaves': 31, 'learning_rate': 0.01, 'min_child_samples': 40, 'feature_fraction': 0.8} | Inner means -> RMSE=293703.6842, MAE=172349.6444, R^2=0.8187
# [2025-10-14 07:51:46] [Outer 5] Combo 4/36 params={'num_leaves': 31, 'learning_rate': 0.01, 'min_child_samples': 40, 'feature_fraction': 1.0} | Inner means -> RMSE=294649.4120, MAE=173470.0854, R^2=0.8175
# [2025-10-14 07:51:51] [Outer 5] Combo 5/36 params={'num_leaves': 31, 'learning_rate': 0.05, 'min_child_samples': 20, 'feature_fraction': 0.8} | Inner means -> RMSE=293803.3716, MAE=172467.5204, R^2=0.8186
# [2025-10-14 07:51:56] [Outer 5] Combo 6/36 params={'num_leaves': 31, 'learning_rate': 0.05, 'min_child_samples': 20, 'feature_fraction': 1.0} | Inner means -> RMSE=296207.5450, MAE=173750.8664, R^2=0.8156
# [2025-10-14 07:52:02] [Outer 5] Combo 7/36 params={'num_leaves': 31, 'learning_rate': 0.05, 'min_child_samples': 40, 'feature_fraction': 0.8} | Inner means -> RMSE=293689.8826, MAE=172401.4530, R^2=0.8187
# [2025-10-14 07:52:07] [Outer 5] Combo 8/36 params={'num_leaves': 31, 'learning_rate': 0.05, 'min_child_samples': 40, 'feature_fraction': 1.0} | Inner means -> RMSE=295147.8481, MAE=173618.6350, R^2=0.8169
# [2025-10-14 07:52:11] [Outer 5] Combo 9/36 params={'num_leaves': 31, 'learning_rate': 0.1, 'min_child_samples': 20, 'feature_fraction': 0.8} | Inner means -> RMSE=296520.7095, MAE=173847.9255, R^2=0.8152
# [2025-10-14 07:52:15] [Outer 5] Combo 10/36 params={'num_leaves': 31, 'learning_rate': 0.1, 'min_child_samples': 20, 'feature_fraction': 1.0} | Inner means -> RMSE=297297.1395, MAE=174574.2333, R^2=0.8143
# [2025-10-14 07:52:18] [Outer 5] Combo 11/36 params={'num_leaves': 31, 'learning_rate': 0.1, 'min_child_samples': 40, 'feature_fraction': 0.8} | Inner means -> RMSE=295726.9815, MAE=173902.5455, R^2=0.8162
# [2025-10-14 07:52:22] [Outer 5] Combo 12/36 params={'num_leaves': 31, 'learning_rate': 0.1, 'min_child_samples': 40, 'feature_fraction': 1.0} | Inner means -> RMSE=296105.5189, MAE=174645.0728, R^2=0.8157
# [2025-10-14 07:52:34] [Outer 5] Combo 13/36 params={'num_leaves': 63, 'learning_rate': 0.01, 'min_child_samples': 20, 'feature_fraction': 0.8} | Inner means -> RMSE=293255.6567, MAE=171508.9803, R^2=0.8193
# [2025-10-14 07:52:48] [Outer 5] Combo 14/36 params={'num_leaves': 63, 'learning_rate': 0.01, 'min_child_samples': 20, 'feature_fraction': 1.0} | Inner means -> RMSE=296874.6152, MAE=173291.8605, R^2=0.8148
# [2025-10-14 07:53:01] [Outer 5] Combo 15/36 params={'num_leaves': 63, 'learning_rate': 0.01, 'min_child_samples': 40, 'feature_fraction': 0.8} | Inner means -> RMSE=294197.9023, MAE=171947.7339, R^2=0.8181
# [2025-10-14 07:53:15] [Outer 5] Combo 16/36 params={'num_leaves': 63, 'learning_rate': 0.01, 'min_child_samples': 40, 'feature_fraction': 1.0} | Inner means -> RMSE=295469.7304, MAE=173221.1204, R^2=0.8165
# [2025-10-14 07:53:20] [Outer 5] Combo 17/36 params={'num_leaves': 63, 'learning_rate': 0.05, 'min_child_samples': 20, 'feature_fraction': 0.8} | Inner means -> RMSE=294377.8629, MAE=172005.3586, R^2=0.8179
# [2025-10-14 07:53:26] [Outer 5] Combo 18/36 params={'num_leaves': 63, 'learning_rate': 0.05, 'min_child_samples': 20, 'feature_fraction': 1.0} | Inner means -> RMSE=296039.4046, MAE=172955.1252, R^2=0.8158
# [2025-10-14 07:53:30] [Outer 5] Combo 19/36 params={'num_leaves': 63, 'learning_rate': 0.05, 'min_child_samples': 40, 'feature_fraction': 0.8} | Inner means -> RMSE=295737.7547, MAE=173363.4433, R^2=0.8162
# [2025-10-14 07:53:36] [Outer 5] Combo 20/36 params={'num_leaves': 63, 'learning_rate': 0.05, 'min_child_samples': 40, 'feature_fraction': 1.0} | Inner means -> RMSE=296407.4958, MAE=173824.6270, R^2=0.8153
# [2025-10-14 07:53:40] [Outer 5] Combo 21/36 params={'num_leaves': 63, 'learning_rate': 0.1, 'min_child_samples': 20, 'feature_fraction': 0.8} | Inner means -> RMSE=296162.9943, MAE=173296.2118, R^2=0.8157
# [2025-10-14 07:53:44] [Outer 5] Combo 22/36 params={'num_leaves': 63, 'learning_rate': 0.1, 'min_child_samples': 20, 'feature_fraction': 1.0} | Inner means -> RMSE=297231.2000, MAE=173796.9810, R^2=0.8143
# [2025-10-14 07:53:48] [Outer 5] Combo 23/36 params={'num_leaves': 63, 'learning_rate': 0.1, 'min_child_samples': 40, 'feature_fraction': 0.8} | Inner means -> RMSE=297315.7617, MAE=174530.9812, R^2=0.8142
# [2025-10-14 07:53:52] [Outer 5] Combo 24/36 params={'num_leaves': 63, 'learning_rate': 0.1, 'min_child_samples': 40, 'feature_fraction': 1.0} | Inner means -> RMSE=296766.9635, MAE=175163.2479, R^2=0.8149
# [2025-10-14 07:54:07] [Outer 5] Combo 25/36 params={'num_leaves': 127, 'learning_rate': 0.01, 'min_child_samples': 20, 'feature_fraction': 0.8} | Inner means -> RMSE=295290.0208, MAE=171581.3359, R^2=0.8168
# [2025-10-14 07:54:21] [Outer 5] Combo 26/36 params={'num_leaves': 127, 'learning_rate': 0.01, 'min_child_samples': 20, 'feature_fraction': 1.0} | Inner means -> RMSE=298711.4618, MAE=173979.8124, R^2=0.8125
# [2025-10-14 07:54:36] [Outer 5] Combo 27/36 params={'num_leaves': 127, 'learning_rate': 0.01, 'min_child_samples': 40, 'feature_fraction': 0.8} | Inner means -> RMSE=295693.7635, MAE=172144.0806, R^2=0.8163
# [2025-10-14 07:54:52] [Outer 5] Combo 28/36 params={'num_leaves': 127, 'learning_rate': 0.01, 'min_child_samples': 40, 'feature_fraction': 1.0} | Inner means -> RMSE=297776.6247, MAE=174163.7613, R^2=0.8136
# [2025-10-14 07:54:58] [Outer 5] Combo 29/36 params={'num_leaves': 127, 'learning_rate': 0.05, 'min_child_samples': 20, 'feature_fraction': 0.8} | Inner means -> RMSE=295867.4203, MAE=172235.6272, R^2=0.8160
# [2025-10-14 07:55:04] [Outer 5] Combo 30/36 params={'num_leaves': 127, 'learning_rate': 0.05, 'min_child_samples': 20, 'feature_fraction': 1.0} | Inner means -> RMSE=299568.1718, MAE=174888.4945, R^2=0.8114
# [2025-10-14 07:55:10] [Outer 5] Combo 31/36 params={'num_leaves': 127, 'learning_rate': 0.05, 'min_child_samples': 40, 'feature_fraction': 0.8} | Inner means -> RMSE=296294.4545, MAE=173321.1047, R^2=0.8155
# [2025-10-14 07:55:16] [Outer 5] Combo 32/36 params={'num_leaves': 127, 'learning_rate': 0.05, 'min_child_samples': 40, 'feature_fraction': 1.0} | Inner means -> RMSE=298386.8085, MAE=174594.3999, R^2=0.8129
# [2025-10-14 07:55:20] [Outer 5] Combo 33/36 params={'num_leaves': 127, 'learning_rate': 0.1, 'min_child_samples': 20, 'feature_fraction': 0.8} | Inner means -> RMSE=296507.1256, MAE=174133.1186, R^2=0.8152
# [2025-10-14 07:55:25] [Outer 5] Combo 34/36 params={'num_leaves': 127, 'learning_rate': 0.1, 'min_child_samples': 20, 'feature_fraction': 1.0} | Inner means -> RMSE=301494.6793, MAE=176156.9180, R^2=0.8090
# [2025-10-14 07:55:29] [Outer 5] Combo 35/36 params={'num_leaves': 127, 'learning_rate': 0.1, 'min_child_samples': 40, 'feature_fraction': 0.8} | Inner means -> RMSE=299240.6333, MAE=175269.8523, R^2=0.8118
# [2025-10-14 07:55:34] [Outer 5] Combo 36/36 params={'num_leaves': 127, 'learning_rate': 0.1, 'min_child_samples': 40, 'feature_fraction': 1.0} | Inner means -> RMSE=300850.5452, MAE=176482.4176, R^2=0.8097
# [2025-10-14 07:55:34] [Outer 5] Best inner params: {'num_leaves': 63, 'learning_rate': 0.01, 'min_child_samples': 20, 'feature_fraction': 0.8} (mean RMSE=293255.6567)
# [2025-10-14 07:55:40] [Outer 5] Validation -> RMSE=336037.6202, MAE=169338.4016, R^2=0.7967
# [2025-10-14 07:55:40] ----------------------------------------------------------------------
# [2025-10-14 07:55:40] Outer fold 6/10
# [2025-10-14 07:55:52] [Outer 6] Combo 1/36 params={'num_leaves': 31, 'learning_rate': 0.01, 'min_child_samples': 20, 'feature_fraction': 0.8} | Inner means -> RMSE=299176.8586, MAE=173232.7335, R^2=0.8146
# [2025-10-14 07:56:04] [Outer 6] Combo 2/36 params={'num_leaves': 31, 'learning_rate': 0.01, 'min_child_samples': 20, 'feature_fraction': 1.0} | Inner means -> RMSE=300043.8270, MAE=174322.2818, R^2=0.8135
# [2025-10-14 07:56:15] [Outer 6] Combo 3/36 params={'num_leaves': 31, 'learning_rate': 0.01, 'min_child_samples': 40, 'feature_fraction': 0.8} | Inner means -> RMSE=298402.9122, MAE=172377.3960, R^2=0.8156
# [2025-10-14 07:56:27] [Outer 6] Combo 4/36 params={'num_leaves': 31, 'learning_rate': 0.01, 'min_child_samples': 40, 'feature_fraction': 1.0} | Inner means -> RMSE=299212.7718, MAE=173479.9334, R^2=0.8146
# [2025-10-14 07:56:32] [Outer 6] Combo 5/36 params={'num_leaves': 31, 'learning_rate': 0.05, 'min_child_samples': 20, 'feature_fraction': 0.8} | Inner means -> RMSE=300061.1493, MAE=173523.6757, R^2=0.8135
# [2025-10-14 07:56:37] [Outer 6] Combo 6/36 params={'num_leaves': 31, 'learning_rate': 0.05, 'min_child_samples': 20, 'feature_fraction': 1.0} | Inner means -> RMSE=300036.7165, MAE=174307.9737, R^2=0.8134
# [2025-10-14 07:56:43] [Outer 6] Combo 7/36 params={'num_leaves': 31, 'learning_rate': 0.05, 'min_child_samples': 40, 'feature_fraction': 0.8} | Inner means -> RMSE=298706.1478, MAE=172548.1927, R^2=0.8152
# [2025-10-14 07:56:48] [Outer 6] Combo 8/36 params={'num_leaves': 31, 'learning_rate': 0.05, 'min_child_samples': 40, 'feature_fraction': 1.0} | Inner means -> RMSE=299257.6391, MAE=173435.0270, R^2=0.8146
# [2025-10-14 07:56:52] [Outer 6] Combo 9/36 params={'num_leaves': 31, 'learning_rate': 0.1, 'min_child_samples': 20, 'feature_fraction': 0.8} | Inner means -> RMSE=302875.7778, MAE=175593.3401, R^2=0.8099
# [2025-10-14 07:56:56] [Outer 6] Combo 10/36 params={'num_leaves': 31, 'learning_rate': 0.1, 'min_child_samples': 20, 'feature_fraction': 1.0} | Inner means -> RMSE=300922.4021, MAE=175092.8922, R^2=0.8124
# [2025-10-14 07:56:59] [Outer 6] Combo 11/36 params={'num_leaves': 31, 'learning_rate': 0.1, 'min_child_samples': 40, 'feature_fraction': 0.8} | Inner means -> RMSE=300748.2642, MAE=175035.1074, R^2=0.8126
# [2025-10-14 07:57:04] [Outer 6] Combo 12/36 params={'num_leaves': 31, 'learning_rate': 0.1, 'min_child_samples': 40, 'feature_fraction': 1.0} | Inner means -> RMSE=300113.4505, MAE=174859.9124, R^2=0.8134
# [2025-10-14 07:57:18] [Outer 6] Combo 13/36 params={'num_leaves': 63, 'learning_rate': 0.01, 'min_child_samples': 20, 'feature_fraction': 0.8} | Inner means -> RMSE=298134.5471, MAE=171864.2617, R^2=0.8159
# [2025-10-14 07:57:33] [Outer 6] Combo 14/36 params={'num_leaves': 63, 'learning_rate': 0.01, 'min_child_samples': 20, 'feature_fraction': 1.0} | Inner means -> RMSE=300106.7156, MAE=173470.2033, R^2=0.8135
# [2025-10-14 07:57:47] [Outer 6] Combo 15/36 params={'num_leaves': 63, 'learning_rate': 0.01, 'min_child_samples': 40, 'feature_fraction': 0.8} | Inner means -> RMSE=299811.7070, MAE=172286.2458, R^2=0.8139
# [2025-10-14 07:58:03] [Outer 6] Combo 16/36 params={'num_leaves': 63, 'learning_rate': 0.01, 'min_child_samples': 40, 'feature_fraction': 1.0} | Inner means -> RMSE=301119.7126, MAE=173760.2423, R^2=0.8123
# [2025-10-14 07:58:08] [Outer 6] Combo 17/36 params={'num_leaves': 63, 'learning_rate': 0.05, 'min_child_samples': 20, 'feature_fraction': 0.8} | Inner means -> RMSE=298900.0701, MAE=172698.3218, R^2=0.8150
# [2025-10-14 07:58:13] [Outer 6] Combo 18/36 params={'num_leaves': 63, 'learning_rate': 0.05, 'min_child_samples': 20, 'feature_fraction': 1.0} | Inner means -> RMSE=301012.4073, MAE=173871.7403, R^2=0.8123
# [2025-10-14 07:58:19] [Outer 6] Combo 19/36 params={'num_leaves': 63, 'learning_rate': 0.05, 'min_child_samples': 40, 'feature_fraction': 0.8} | Inner means -> RMSE=300241.5395, MAE=173056.0886, R^2=0.8134
# [2025-10-14 07:58:24] [Outer 6] Combo 20/36 params={'num_leaves': 63, 'learning_rate': 0.05, 'min_child_samples': 40, 'feature_fraction': 1.0} | Inner means -> RMSE=302098.9188, MAE=174218.4773, R^2=0.8111
# [2025-10-14 07:58:28] [Outer 6] Combo 21/36 params={'num_leaves': 63, 'learning_rate': 0.1, 'min_child_samples': 20, 'feature_fraction': 0.8} | Inner means -> RMSE=302453.0521, MAE=175227.8664, R^2=0.8106
# [2025-10-14 07:58:32] [Outer 6] Combo 22/36 params={'num_leaves': 63, 'learning_rate': 0.1, 'min_child_samples': 20, 'feature_fraction': 1.0} | Inner means -> RMSE=303387.1873, MAE=175808.6421, R^2=0.8094
# [2025-10-14 07:58:37] [Outer 6] Combo 23/36 params={'num_leaves': 63, 'learning_rate': 0.1, 'min_child_samples': 40, 'feature_fraction': 0.8} | Inner means -> RMSE=302554.8343, MAE=174921.4690, R^2=0.8105
# [2025-10-14 07:58:42] [Outer 6] Combo 24/36 params={'num_leaves': 63, 'learning_rate': 0.1, 'min_child_samples': 40, 'feature_fraction': 1.0} | Inner means -> RMSE=304836.5391, MAE=176225.4726, R^2=0.8077
# [2025-10-14 07:58:57] [Outer 6] Combo 25/36 params={'num_leaves': 127, 'learning_rate': 0.01, 'min_child_samples': 20, 'feature_fraction': 0.8} | Inner means -> RMSE=300786.2881, MAE=172364.6576, R^2=0.8127
# [2025-10-14 07:59:13] [Outer 6] Combo 26/36 params={'num_leaves': 127, 'learning_rate': 0.01, 'min_child_samples': 20, 'feature_fraction': 1.0} | Inner means -> RMSE=304490.3421, MAE=174788.0579, R^2=0.8080
# [2025-10-14 07:59:32] [Outer 6] Combo 27/36 params={'num_leaves': 127, 'learning_rate': 0.01, 'min_child_samples': 40, 'feature_fraction': 0.8} | Inner means -> RMSE=301806.6649, MAE=173140.3141, R^2=0.8115
# [2025-10-14 07:59:53] [Outer 6] Combo 28/36 params={'num_leaves': 127, 'learning_rate': 0.01, 'min_child_samples': 40, 'feature_fraction': 1.0} | Inner means -> RMSE=304332.1531, MAE=174888.2006, R^2=0.8083
# [2025-10-14 07:59:59] [Outer 6] Combo 29/36 params={'num_leaves': 127, 'learning_rate': 0.05, 'min_child_samples': 20, 'feature_fraction': 0.8} | Inner means -> RMSE=301661.7480, MAE=173575.8684, R^2=0.8116
# [2025-10-14 08:00:05] [Outer 6] Combo 30/36 params={'num_leaves': 127, 'learning_rate': 0.05, 'min_child_samples': 20, 'feature_fraction': 1.0} | Inner means -> RMSE=304291.5940, MAE=175006.8991, R^2=0.8083
# [2025-10-14 08:00:11] [Outer 6] Combo 31/36 params={'num_leaves': 127, 'learning_rate': 0.05, 'min_child_samples': 40, 'feature_fraction': 0.8} | Inner means -> RMSE=303073.9393, MAE=174130.4312, R^2=0.8099
# [2025-10-14 08:00:18] [Outer 6] Combo 32/36 params={'num_leaves': 127, 'learning_rate': 0.05, 'min_child_samples': 40, 'feature_fraction': 1.0} | Inner means -> RMSE=305662.1289, MAE=176279.2101, R^2=0.8066
# [2025-10-14 08:00:23] [Outer 6] Combo 33/36 params={'num_leaves': 127, 'learning_rate': 0.1, 'min_child_samples': 20, 'feature_fraction': 0.8} | Inner means -> RMSE=303531.5278, MAE=175307.4784, R^2=0.8092
# [2025-10-14 08:00:27] [Outer 6] Combo 34/36 params={'num_leaves': 127, 'learning_rate': 0.1, 'min_child_samples': 20, 'feature_fraction': 1.0} | Inner means -> RMSE=305795.8494, MAE=176504.1763, R^2=0.8064
# [2025-10-14 08:00:32] [Outer 6] Combo 35/36 params={'num_leaves': 127, 'learning_rate': 0.1, 'min_child_samples': 40, 'feature_fraction': 0.8} | Inner means -> RMSE=304356.8185, MAE=175805.1754, R^2=0.8083
# [2025-10-14 08:00:37] [Outer 6] Combo 36/36 params={'num_leaves': 127, 'learning_rate': 0.1, 'min_child_samples': 40, 'feature_fraction': 1.0} | Inner means -> RMSE=307088.0890, MAE=177453.0045, R^2=0.8048
# [2025-10-14 08:00:37] [Outer 6] Best inner params: {'num_leaves': 63, 'learning_rate': 0.01, 'min_child_samples': 20, 'feature_fraction': 0.8} (mean RMSE=298134.5471)
# [2025-10-14 08:00:41] [Outer 6] Validation -> RMSE=287608.5038, MAE=171135.8060, R^2=0.8284
# [2025-10-14 08:00:41] ----------------------------------------------------------------------
# [2025-10-14 08:00:41] Outer fold 7/10
# [2025-10-14 08:00:53] [Outer 7] Combo 1/36 params={'num_leaves': 31, 'learning_rate': 0.01, 'min_child_samples': 20, 'feature_fraction': 0.8} | Inner means -> RMSE=300565.8295, MAE=174290.7062, R^2=0.8114
# [2025-10-14 08:01:05] [Outer 7] Combo 2/36 params={'num_leaves': 31, 'learning_rate': 0.01, 'min_child_samples': 20, 'feature_fraction': 1.0} | Inner means -> RMSE=302207.2111, MAE=175448.7746, R^2=0.8093
# [2025-10-14 08:01:16] [Outer 7] Combo 3/36 params={'num_leaves': 31, 'learning_rate': 0.01, 'min_child_samples': 40, 'feature_fraction': 0.8} | Inner means -> RMSE=300759.2930, MAE=174151.7154, R^2=0.8112
# ...
# [2025-10-14 10:41:23] ----------------------------------------------------------------------
# [2025-10-14 10:41:23] Outer fold 9/10
# [2025-10-14 10:41:36] [Outer 9] Combo 1/36 params={'num_leaves': 31, 'learning_rate': 0.01, 'min_child_samples': 20, 'feature_fraction': 0.8} | Inner means -> RMSE=297142.5135, MAE=171587.5436, R^2=0.8125
# [2025-10-14 10:41:49] [Outer 9] Combo 2/36 params={'num_leaves': 31, 'learning_rate': 0.01, 'min_child_samples': 20, 'feature_fraction': 1.0} | Inner means -> RMSE=298286.3597, MAE=173086.5586, R^2=0.8111
# [2025-10-14 10:42:01] [Outer 9] Combo 3/36 params={'num_leaves': 31, 'learning_rate': 0.01, 'min_child_samples': 40, 'feature_fraction': 0.8} | Inner means -> RMSE=297450.4029, MAE=171905.0662, R^2=0.8122
# [2025-10-14 10:42:13] [Outer 9] Combo 4/36 params={'num_leaves': 31, 'learning_rate': 0.01, 'min_child_samples': 40, 'feature_fraction': 1.0} | Inner means -> RMSE=298615.7797, MAE=173048.7707, R^2=0.8107
# [2025-10-14 10:42:18] [Outer 9] Combo 5/36 params={'num_leaves': 31, 'learning_rate': 0.05, 'min_child_samples': 20, 'feature_fraction': 0.8} | Inner means -> RMSE=298963.7903, MAE=172280.0406, R^2=0.8102
# [2025-10-14 10:42:24] [Outer 9] Combo 6/36 params={'num_leaves': 31, 'learning_rate': 0.05, 'min_child_samples': 20, 'feature_fraction': 1.0} | Inner means -> RMSE=298439.5003, MAE=172673.8132, R^2=0.8109
# [2025-10-14 10:42:29] [Outer 9] Combo 7/36 params={'num_leaves': 31, 'learning_rate': 0.05, 'min_child_samples': 40, 'feature_fraction': 0.8} | Inner means -> RMSE=297507.7286, MAE=172105.0975, R^2=0.8121
# [2025-10-14 10:42:35] [Outer 9] Combo 8/36 params={'num_leaves': 31, 'learning_rate': 0.05, 'min_child_samples': 40, 'feature_fraction': 1.0} | Inner means -> RMSE=299333.6422, MAE=173003.7522, R^2=0.8098
# [2025-10-14 10:42:39] [Outer 9] Combo 9/36 params={'num_leaves': 31, 'learning_rate': 0.1, 'min_child_samples': 20, 'feature_fraction': 0.8} | Inner means -> RMSE=301354.7866, MAE=173686.3783, R^2=0.8072
# [2025-10-14 10:42:43] [Outer 9] Combo 10/36 params={'num_leaves': 31, 'learning_rate': 0.1, 'min_child_samples': 20, 'feature_fraction': 1.0} | Inner means -> RMSE=300489.7041, MAE=174035.1044, R^2=0.8084
# [2025-10-14 10:42:47] [Outer 9] Combo 11/36 params={'num_leaves': 31, 'learning_rate': 0.1, 'min_child_samples': 40, 'feature_fraction': 0.8} | Inner means -> RMSE=298885.7513, MAE=173514.9336, R^2=0.8104
# [2025-10-14 10:42:51] [Outer 9] Combo 12/36 params={'num_leaves': 31, 'learning_rate': 0.1, 'min_child_samples': 40, 'feature_fraction': 1.0} | Inner means -> RMSE=299943.9312, MAE=174159.1324, R^2=0.8091
# [2025-10-14 10:43:06] [Outer 9] Combo 13/36 params={'num_leaves': 63, 'learning_rate': 0.01, 'min_child_samples': 20, 'feature_fraction': 0.8} | Inner means -> RMSE=296874.2119, MAE=170436.3311, R^2=0.8129
# [2025-10-14 10:43:21] [Outer 9] Combo 14/36 params={'num_leaves': 63, 'learning_rate': 0.01, 'min_child_samples': 20, 'feature_fraction': 1.0} | Inner means -> RMSE=299898.7536, MAE=172212.7136, R^2=0.8090
# [2025-10-14 10:43:35] [Outer 9] Combo 15/36 params={'num_leaves': 63, 'learning_rate': 0.01, 'min_child_samples': 40, 'feature_fraction': 0.8} | Inner means -> RMSE=297818.2163, MAE=171464.4236, R^2=0.8117
# [2025-10-14 10:43:49] [Outer 9] Combo 16/36 params={'num_leaves': 63, 'learning_rate': 0.01, 'min_child_samples': 40, 'feature_fraction': 1.0} | Inner means -> RMSE=300244.1702, MAE=173115.7036, R^2=0.8086
# [2025-10-14 10:43:54] [Outer 9] Combo 17/36 params={'num_leaves': 63, 'learning_rate': 0.05, 'min_child_samples': 20, 'feature_fraction': 0.8} | Inner means -> RMSE=298895.0462, MAE=171566.2044, R^2=0.8103
# [2025-10-14 10:44:00] [Outer 9] Combo 18/36 params={'num_leaves': 63, 'learning_rate': 0.05, 'min_child_samples': 20, 'feature_fraction': 1.0} | Inner means -> RMSE=300221.4455, MAE=172568.0684, R^2=0.8086
# [2025-10-14 10:44:05] [Outer 9] Combo 19/36 params={'num_leaves': 63, 'learning_rate': 0.05, 'min_child_samples': 40, 'feature_fraction': 0.8} | Inner means -> RMSE=298742.8533, MAE=172334.5703, R^2=0.8105
# [2025-10-14 10:44:12] [Outer 9] Combo 20/36 params={'num_leaves': 63, 'learning_rate': 0.05, 'min_child_samples': 40, 'feature_fraction': 1.0} | Inner means -> RMSE=300349.4823, MAE=173359.5129, R^2=0.8085
# [2025-10-14 10:44:16] [Outer 9] Combo 21/36 params={'num_leaves': 63, 'learning_rate': 0.1, 'min_child_samples': 20, 'feature_fraction': 0.8} | Inner means -> RMSE=299709.5193, MAE=172959.0240, R^2=0.8093
# [2025-10-14 10:44:20] [Outer 9] Combo 22/36 params={'num_leaves': 63, 'learning_rate': 0.1, 'min_child_samples': 20, 'feature_fraction': 1.0} | Inner means -> RMSE=301582.0694, MAE=173310.3625, R^2=0.8068
# [2025-10-14 10:44:25] [Outer 9] Combo 23/36 params={'num_leaves': 63, 'learning_rate': 0.1, 'min_child_samples': 40, 'feature_fraction': 0.8} | Inner means -> RMSE=300214.7774, MAE=173676.7303, R^2=0.8087
# [2025-10-14 10:44:29] [Outer 9] Combo 24/36 params={'num_leaves': 63, 'learning_rate': 0.1, 'min_child_samples': 40, 'feature_fraction': 1.0} | Inner means -> RMSE=301252.4430, MAE=174843.9043, R^2=0.8074
# [2025-10-14 10:44:45] [Outer 9] Combo 25/36 params={'num_leaves': 127, 'learning_rate': 0.01, 'min_child_samples': 20, 'feature_fraction': 0.8} | Inner means -> RMSE=298441.5331, MAE=170840.0847, R^2=0.8108
# [2025-10-14 10:44:59] [Outer 9] Combo 26/36 params={'num_leaves': 127, 'learning_rate': 0.01, 'min_child_samples': 20, 'feature_fraction': 1.0} | Inner means -> RMSE=301841.7457, MAE=172802.9837, R^2=0.8065
# [2025-10-14 10:45:16] [Outer 9] Combo 27/36 params={'num_leaves': 127, 'learning_rate': 0.01, 'min_child_samples': 40, 'feature_fraction': 0.8} | Inner means -> RMSE=298425.2164, MAE=171002.3823, R^2=0.8109
# [2025-10-14 10:45:36] [Outer 9] Combo 28/36 params={'num_leaves': 127, 'learning_rate': 0.01, 'min_child_samples': 40, 'feature_fraction': 1.0} | Inner means -> RMSE=301261.7186, MAE=172815.4639, R^2=0.8073
# [2025-10-14 10:45:42] [Outer 9] Combo 29/36 params={'num_leaves': 127, 'learning_rate': 0.05, 'min_child_samples': 20, 'feature_fraction': 0.8} | Inner means -> RMSE=299346.8117, MAE=172139.3474, R^2=0.8097
# [2025-10-14 10:45:48] [Outer 9] Combo 30/36 params={'num_leaves': 127, 'learning_rate': 0.05, 'min_child_samples': 20, 'feature_fraction': 1.0} | Inner means -> RMSE=301632.6210, MAE=172818.5553, R^2=0.8068
# [2025-10-14 10:45:55] [Outer 9] Combo 31/36 params={'num_leaves': 127, 'learning_rate': 0.05, 'min_child_samples': 40, 'feature_fraction': 0.8} | Inner means -> RMSE=299485.6166, MAE=172233.1220, R^2=0.8096
# [2025-10-14 10:46:01] [Outer 9] Combo 32/36 params={'num_leaves': 127, 'learning_rate': 0.05, 'min_child_samples': 40, 'feature_fraction': 1.0} | Inner means -> RMSE=302131.1959, MAE=173332.0525, R^2=0.8062
# [2025-10-14 10:46:06] [Outer 9] Combo 33/36 params={'num_leaves': 127, 'learning_rate': 0.1, 'min_child_samples': 20, 'feature_fraction': 0.8} | Inner means -> RMSE=301488.0331, MAE=173519.5727, R^2=0.8070
# [2025-10-14 10:46:11] [Outer 9] Combo 34/36 params={'num_leaves': 127, 'learning_rate': 0.1, 'min_child_samples': 20, 'feature_fraction': 1.0} | Inner means -> RMSE=302898.9141, MAE=174093.1742, R^2=0.8052
# [2025-10-14 10:46:16] [Outer 9] Combo 35/36 params={'num_leaves': 127, 'learning_rate': 0.1, 'min_child_samples': 40, 'feature_fraction': 0.8} | Inner means -> RMSE=300386.7348, MAE=173680.6341, R^2=0.8085
# [2025-10-14 10:46:21] [Outer 9] Combo 36/36 params={'num_leaves': 127, 'learning_rate': 0.1, 'min_child_samples': 40, 'feature_fraction': 1.0} | Inner means -> RMSE=302748.9099, MAE=174350.8746, R^2=0.8054
# [2025-10-14 10:46:21] [Outer 9] Best inner params: {'num_leaves': 63, 'learning_rate': 0.01, 'min_child_samples': 20, 'feature_fraction': 0.8} (mean RMSE=296874.2119)
# [2025-10-14 10:46:27] [Outer 9] Validation -> RMSE=292609.0355, MAE=162223.1308, R^2=0.8171
# [2025-10-14 10:46:27] ----------------------------------------------------------------------
# [2025-10-14 10:46:27] Outer fold 10/10
# [2025-10-14 10:46:38] [Outer 10] Combo 1/36 params={'num_leaves': 31, 'learning_rate': 0.01, 'min_child_samples': 20, 'feature_fraction': 0.8} | Inner means -> RMSE=301889.7552, MAE=173447.3612, R^2=0.8068
# [2025-10-14 10:46:51] [Outer 10] Combo 2/36 params={'num_leaves': 31, 'learning_rate': 0.01, 'min_child_samples': 20, 'feature_fraction': 1.0} | Inner means -> RMSE=302888.3576, MAE=174089.1724, R^2=0.8055
# [2025-10-14 10:47:03] [Outer 10] Combo 3/36 params={'num_leaves': 31, 'learning_rate': 0.01, 'min_child_samples': 40, 'feature_fraction': 0.8} | Inner means -> RMSE=302372.6289, MAE=172815.9064, R^2=0.8061
# [2025-10-14 10:47:14] [Outer 10] Combo 4/36 params={'num_leaves': 31, 'learning_rate': 0.01, 'min_child_samples': 40, 'feature_fraction': 1.0} | Inner means -> RMSE=303945.7743, MAE=174329.9310, R^2=0.8041
# [2025-10-14 10:47:19] [Outer 10] Combo 5/36 params={'num_leaves': 31, 'learning_rate': 0.05, 'min_child_samples': 20, 'feature_fraction': 0.8} | Inner means -> RMSE=302747.2928, MAE=174005.6698, R^2=0.8057
# [2025-10-14 10:47:24] [Outer 10] Combo 6/36 params={'num_leaves': 31, 'learning_rate': 0.05, 'min_child_samples': 20, 'feature_fraction': 1.0} | Inner means -> RMSE=303886.7927, MAE=174607.0774, R^2=0.8042
# [2025-10-14 10:47:29] [Outer 10] Combo 7/36 params={'num_leaves': 31, 'learning_rate': 0.05, 'min_child_samples': 40, 'feature_fraction': 0.8} | Inner means -> RMSE=303523.3745, MAE=173639.4253, R^2=0.8047
# [2025-10-14 10:47:34] [Outer 10] Combo 8/36 params={'num_leaves': 31, 'learning_rate': 0.05, 'min_child_samples': 40, 'feature_fraction': 1.0} | Inner means -> RMSE=304116.7214, MAE=174338.8757, R^2=0.8039
# [2025-10-14 10:47:37] [Outer 10] Combo 9/36 params={'num_leaves': 31, 'learning_rate': 0.1, 'min_child_samples': 20, 'feature_fraction': 0.8} | Inner means -> RMSE=304566.3106, MAE=175223.9531, R^2=0.8032
# [2025-10-14 10:47:42] [Outer 10] Combo 10/36 params={'num_leaves': 31, 'learning_rate': 0.1, 'min_child_samples': 20, 'feature_fraction': 1.0} | Inner means -> RMSE=304007.9270, MAE=174956.8422, R^2=0.8041
# [2025-10-14 10:47:46] [Outer 10] Combo 11/36 params={'num_leaves': 31, 'learning_rate': 0.1, 'min_child_samples': 40, 'feature_fraction': 0.8} | Inner means -> RMSE=303700.3255, MAE=174410.1759, R^2=0.8044
# [2025-10-14 10:47:50] [Outer 10] Combo 12/36 params={'num_leaves': 31, 'learning_rate': 0.1, 'min_child_samples': 40, 'feature_fraction': 1.0} | Inner means -> RMSE=305570.5693, MAE=174885.1729, R^2=0.8020
# [2025-10-14 10:48:03] [Outer 10] Combo 13/36 params={'num_leaves': 63, 'learning_rate': 0.01, 'min_child_samples': 20, 'feature_fraction': 0.8} | Inner means -> RMSE=302180.0255, MAE=172116.4813, R^2=0.8064
# [2025-10-14 10:48:15] [Outer 10] Combo 14/36 params={'num_leaves': 63, 'learning_rate': 0.01, 'min_child_samples': 20, 'feature_fraction': 1.0} | Inner means -> RMSE=304435.6425, MAE=173408.8306, R^2=0.8035
# [2025-10-14 10:48:27] [Outer 10] Combo 15/36 params={'num_leaves': 63, 'learning_rate': 0.01, 'min_child_samples': 40, 'feature_fraction': 0.8} | Inner means -> RMSE=303071.8056, MAE=171997.7782, R^2=0.8053
# [2025-10-14 10:48:39] [Outer 10] Combo 16/36 params={'num_leaves': 63, 'learning_rate': 0.01, 'min_child_samples': 40, 'feature_fraction': 1.0} | Inner means -> RMSE=305229.7520, MAE=173593.6539, R^2=0.8025
# [2025-10-14 10:48:45] [Outer 10] Combo 17/36 params={'num_leaves': 63, 'learning_rate': 0.05, 'min_child_samples': 20, 'feature_fraction': 0.8} | Inner means -> RMSE=303103.9986, MAE=172739.7024, R^2=0.8052
# [2025-10-14 10:48:50] [Outer 10] Combo 18/36 params={'num_leaves': 63, 'learning_rate': 0.05, 'min_child_samples': 20, 'feature_fraction': 1.0} | Inner means -> RMSE=304789.5775, MAE=173557.5986, R^2=0.8030
# [2025-10-14 10:48:55] [Outer 10] Combo 19/36 params={'num_leaves': 63, 'learning_rate': 0.05, 'min_child_samples': 40, 'feature_fraction': 0.8} | Inner means -> RMSE=302899.1011, MAE=172109.6368, R^2=0.8055
# [2025-10-14 10:49:00] [Outer 10] Combo 20/36 params={'num_leaves': 63, 'learning_rate': 0.05, 'min_child_samples': 40, 'feature_fraction': 1.0} | Inner means -> RMSE=305000.8120, MAE=173670.1511, R^2=0.8028
# [2025-10-14 10:49:05] [Outer 10] Combo 21/36 params={'num_leaves': 63, 'learning_rate': 0.1, 'min_child_samples': 20, 'feature_fraction': 0.8} | Inner means -> RMSE=304891.8437, MAE=173916.2780, R^2=0.8029
# [2025-10-14 10:49:09] [Outer 10] Combo 22/36 params={'num_leaves': 63, 'learning_rate': 0.1, 'min_child_samples': 20, 'feature_fraction': 1.0} | Inner means -> RMSE=306306.7755, MAE=174835.0168, R^2=0.8011
# [2025-10-14 10:49:13] [Outer 10] Combo 23/36 params={'num_leaves': 63, 'learning_rate': 0.1, 'min_child_samples': 40, 'feature_fraction': 0.8} | Inner means -> RMSE=304316.9401, MAE=173854.5559, R^2=0.8037
# [2025-10-14 10:49:17] [Outer 10] Combo 24/36 params={'num_leaves': 63, 'learning_rate': 0.1, 'min_child_samples': 40, 'feature_fraction': 1.0} | Inner means -> RMSE=305831.8023, MAE=175073.1527, R^2=0.8017
# [2025-10-14 10:49:33] [Outer 10] Combo 25/36 params={'num_leaves': 127, 'learning_rate': 0.01, 'min_child_samples': 20, 'feature_fraction': 0.8} | Inner means -> RMSE=302827.6417, MAE=171341.0238, R^2=0.8056
# [2025-10-14 10:49:50] [Outer 10] Combo 26/36 params={'num_leaves': 127, 'learning_rate': 0.01, 'min_child_samples': 20, 'feature_fraction': 1.0} | Inner means -> RMSE=305684.6616, MAE=173259.3572, R^2=0.8019
# [2025-10-14 10:50:03] [Outer 10] Combo 27/36 params={'num_leaves': 127, 'learning_rate': 0.01, 'min_child_samples': 40, 'feature_fraction': 0.8} | Inner means -> RMSE=304723.5065, MAE=171747.1725, R^2=0.8032
# [2025-10-14 10:50:18] [Outer 10] Combo 28/36 params={'num_leaves': 127, 'learning_rate': 0.01, 'min_child_samples': 40, 'feature_fraction': 1.0} | Inner means -> RMSE=307333.9440, MAE=174094.6181, R^2=0.7998
# [2025-10-14 10:50:24] [Outer 10] Combo 29/36 params={'num_leaves': 127, 'learning_rate': 0.05, 'min_child_samples': 20, 'feature_fraction': 0.8} | Inner means -> RMSE=303578.1404, MAE=172280.1311, R^2=0.8046
# [2025-10-14 10:50:30] [Outer 10] Combo 30/36 params={'num_leaves': 127, 'learning_rate': 0.05, 'min_child_samples': 20, 'feature_fraction': 1.0} | Inner means -> RMSE=306013.7178, MAE=173529.5838, R^2=0.8015
# [2025-10-14 10:50:37] [Outer 10] Combo 31/36 params={'num_leaves': 127, 'learning_rate': 0.05, 'min_child_samples': 40, 'feature_fraction': 0.8} | Inner means -> RMSE=305313.2852, MAE=172718.2266, R^2=0.8024
# [2025-10-14 10:50:43] [Outer 10] Combo 32/36 params={'num_leaves': 127, 'learning_rate': 0.05, 'min_child_samples': 40, 'feature_fraction': 1.0} | Inner means -> RMSE=307283.2731, MAE=174258.8199, R^2=0.7998
# [2025-10-14 10:50:47] [Outer 10] Combo 33/36 params={'num_leaves': 127, 'learning_rate': 0.1, 'min_child_samples': 20, 'feature_fraction': 0.8} | Inner means -> RMSE=305212.8681, MAE=173785.6738, R^2=0.8025
# [2025-10-14 10:50:53] [Outer 10] Combo 34/36 params={'num_leaves': 127, 'learning_rate': 0.1, 'min_child_samples': 20, 'feature_fraction': 1.0} | Inner means -> RMSE=308032.6174, MAE=175205.0244, R^2=0.7989
# [2025-10-14 10:50:57] [Outer 10] Combo 35/36 params={'num_leaves': 127, 'learning_rate': 0.1, 'min_child_samples': 40, 'feature_fraction': 0.8} | Inner means -> RMSE=307172.6452, MAE=174387.5334, R^2=0.8000
# [2025-10-14 10:51:02] [Outer 10] Combo 36/36 params={'num_leaves': 127, 'learning_rate': 0.1, 'min_child_samples': 40, 'feature_fraction': 1.0} | Inner means -> RMSE=308243.2984, MAE=174905.2663, R^2=0.7986
# [2025-10-14 10:51:02] [Outer 10] Best inner params: {'num_leaves': 31, 'learning_rate': 0.01, 'min_child_samples': 20, 'feature_fraction': 0.8} (mean RMSE=301889.7552)
# [2025-10-14 10:51:06] [Outer 10] Validation -> RMSE=275484.0787, MAE=166716.6313, R^2=0.8361
# [2025-10-14 10:51:06] Outer summary -> RMSE mean=292208.2968±22252.6462, MAE mean=168759.9019±5878.9416, R^2 mean=0.8177±0.0223
# Saved per-region summary to summary_west.txt and log to log_west.txt
# \nWrote combined master summary (with per-fold metrics) to experiment_summary_all_regions.txt
